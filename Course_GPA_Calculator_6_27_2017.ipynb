# %% [markdown]
# ### Course GPA Calculator
# Below I created a code to run through the class data to give me the GPA's according to the specific major category that had been added to the original excel file, On a previous verson of my code there is the list of those categories, if you are worried what majors are in them.
#
#
# Below, I import then add together the two data sets, then check them so that the len is above 551,937. For me it says more because the way that the categories were added therefor the excel for some reason is counting the extra blank spaces but this is not an issue in the function. I have it print the top of the data so that you can see what the data looks like.
#
#
# In the function, I first sort them by course and subject (example: "183" and "PHY"). Then using the column with the major categories in them loop through and add the grade numbers to a dictonay which will store the data, then I will average them out and print out the GPA's, these specifics are commented out in the cell with the function.

# %%
import matplotlib.pyplot as plt #used to make the plots below
# %matplotlib inline  
#makes them print in the jupyter notebook
import numpy as np              #because numpy is amazing....       
import pandas as pd             #Use this for data loading and statistics

# %%
classes_FS01=pd.read_excel("Classes_FS01-US16_1.xlsx")       #reads the data file and saves it
classes_FS01_2=pd.read_excel("Classes_FS01-US16_1.xlsx")

# %%
# add both parts together, Make sure they are 551,937 total before moving on!
df_class=classes_FS01.append(classes_FS01_2,ignore_index=True)

# %%
print(len(df_class["placeholderID"]))
print(df_class.head())
# Out:
# 549998
#                           placeholderID  term_seq_id term_code subj_code  \
# 0  97758DD4-7286-4A19-BA6C-00005FE6CFA3         1014      FS01       PHY
# 1  97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       MTH
# 2  97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       PHY
# 3  97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       PHY
# 4  592FB87B-B37F-476D-B7F0-0001F057D6A6         1014      FS01       MTH
#
#   crse_code  sctn_code grade_code repeat_status_flag  major_code  \
# 0       251       24.0        2.5                         3611.0
# 1       126        5.0        3.0                 SR      3611.0
# 2       232        1.0        1.0                         3611.0
# 3       252       20.0        1.5                         3611.0
# 4       110        8.0        2.0                         4494.0
#
#         major_name    dept_name    college_name  major_type
# 0   Earth Science           NaN             NaN  Other STEM
# ...

# %%
def Average_GPAs_of_Major_category(subject,course,course_name):

    print('\x1b[1;32m' + " GPA's for Majors in"+'\x1b[0m',subject,course,"       ",course_name) #this formats and print the title of the output
    class_sort=df_class[df_class.crse_code==course]              #this will create a new data set will just the course
    subject_sort=class_sort[class_sort.subj_code==subject]       #this will sort it through even more with the subject
    
    unique_major_type=list(subject_sort["major_type"].unique()) #this creates a list of all the major categories
    unique_major_type=np.sort(unique_major_type)                #this sorts the list so that it is the same each time

    fmt_str = "{:21} | GPA: {:1.4f} | Sample Size: {:<6}"     #this is the format of the output
    unique_grade =["0.0","1.0","1.5","2.0","2.5","3.0","3.5","4.0"] #this will be the grades we will look for
    total_counts=0                   #this will be added to, to give us the total sample size for the course

    for major_cat in unique_major_type:
        major_cat_sort=subject_sort[subject_sort.major_type==major_cat] #this will loop through each major category 
        if len(major_cat_sort)==0:              #this leaves out the major categories if there is no counts for it
            continue
            

        result= {}                                     #We will add the grade counts to a dictionary to use later
        for grade in unique_grade:                     #loops through the grades and counts them
            grade_term_sort=major_cat_sort[major_cat_sort.grade_code==grade] #this will now take the majors and sort out the grades
            
            if grade not in result:                      #this is to not count if there is no counts for the grade
                result[grade]=[]                          #adds a 0 to the count
            result[grade].append(len(grade_term_sort))    #this will append the counts to the dictonary for each grade
        #print(result)

        top=0                         #this will be the numerator to find the average gpa
        bottom=0                      #this will be the demoninator to find the average with
        for key,value in result.items():  #this will loop through the dictonary created above
            top += float(key)*value[0]     #this will take the grade, make it a float, then multiply the counts
            bottom += value[0]             #this takes just the counts to make the denominator
        if bottom != 0:
            average=top/bottom             #this now averages the gpa's of that major throughout the years
        else:
            print("{:21} | GPA: NaN    | Sample Size: None ".format(major_cat))
            continue 
            
        sample_size=np.sum(list(result.values()))   #this will count the number of majors in the sample
        total_counts=total_counts+sample_size       #this will add each major's counts to a totaling counts

        
                #this will print out the major category, average gpa of that category, 
                #and the sample size of the number of students averaged through
        print(fmt_str.format( major_cat, average,sample_size))    

    all_result={}                                                     #we will add the grades and counts to this dictonary
    for grades in unique_grade:                                       #this will loop through for the grades
        grade_term_sort=subject_sort[subject_sort.grade_code==grades] #this will now take the terms and sort out the grades
        if grade not in all_result:                                 #this is to not count if there is no counts for the grade           
            all_result[grades]=[]                                   #adds a 0 to the count
        all_result[grades].append(len(grade_term_sort))             #this will append the counts to the dictonary for each grade

    for key,value in all_result.items():       #this will now loop through the overall dictonary
        top += float(key)*value[0]             #this will take the grade, make it a float, then multiply the counts
        bottom += value[0]                     #this takes just the counts to make the denominator
    all_average=top/bottom                     #this now averages the gpa's of that major throughout the years

    print(fmt_str.format('\x1b[1;33m'+'Overall              '+'\x1b[0m',all_average,total_counts))
    print(" ")

# %% [markdown]
# #### Common Physics major course
# Below I will run the function through the standard physics courses required for a physics major, the astrophyics majors are not required to take a few of the 490 (Physics Senior Thesis). Phyics 183 and 184 are the physics  "for Scientists and Engineers" and physics 231 and 232 are their counterparts.

# %%
Average_GPAs_of_Major_category("PHY","183","Physics for Scientists and Engineers I")
Average_GPAs_of_Major_category('PHY',"231","Introductory Physics II ")


Average_GPAs_of_Major_category("PHY","184","Physics for Scientists and Engineers II")
Average_GPAs_of_Major_category('PHY',"232","Introductory Physics II ")

Average_GPAs_of_Major_category('PHY',"191","Physics Laboratory for Scientists, I")
Average_GPAs_of_Major_category('PHY',"192","Physics Laboratory for Scientists, II")

Average_GPAs_of_Major_category('PHY',"215","Thermodynamics & Modrn Physics")
Average_GPAs_of_Major_category("PHY","321","Classical Mechanics I")

Average_GPAs_of_Major_category('PHY',"410","Thermal and Statistical Physics")
Average_GPAs_of_Major_category('PHY',"440","Electronics")

Average_GPAs_of_Major_category('PHY',"471","Quantum Physics I " )
Average_GPAs_of_Major_category('PHY',"481"," Electricity and Magnetism I")

Average_GPAs_of_Major_category('PHY',"490","Senior Thesis")
# Out:
#  GPA's for Majors in PHY 183         Physics for Scientists and Engineers I
# Education             | GPA: 2.6500 | Sample Size: 20
# Engineering           | GPA: 3.0630 | Sample Size: 8954
# Lyman Briggs          | GPA: 2.9500 | Sample Size: 420
# No Preference         | GPA: 2.8559 | Sample Size: 236
# Other Major           | GPA: 3.3000 | Sample Size: 10
# Other STEM            | GPA: 2.9117 | Sample Size: 5110
# Physics/Astrophysics  | GPA: 2.7055 | Sample Size: 472
# non STEM              | GPA: 2.4217 | Sample Size: 562
# Overall               | GPA: 2.9548 | Sample Size: 15784
#
#  GPA's for Majors in PHY 231         Introductory Physics II
# Education             | GPA: 2.7941 | Sample Size: 238
# Engineering           | GPA: 2.6765 | Sample Size: 1558
# Lyman Briggs          | GPA: 2.8739 | Sample Size: 468
# No Preference         | GPA: 2.7740 | Sample Size: 208
# Other Major           | GPA: 2.5000 | Sample Size: 2
# ...

# %% [markdown]
# #### Common Math Courses
# Below are the common math courses that astrophysics/physics majors have to take. I added the two Lyman Briggs courses because there was a few astro and phy majors in those classes.

# %%
Average_GPAs_of_Major_category('MTH',"132", 'Calculus 1')
Average_GPAs_of_Major_category('LB',"118" , 'LB Calculus I')

Average_GPAs_of_Major_category('MTH',"133", 'Calculus II')
Average_GPAs_of_Major_category('LB',"119" , 'LB Calculus II')
Average_GPAs_of_Major_category('LB',"220", 'LB Calculus III')

Average_GPAs_of_Major_category('MTH',"234",  'Multivariable Calculus')
Average_GPAs_of_Major_category('MTH',"235", 'Differential Equations' )

Average_GPAs_of_Major_category('MTH',"309", 'Linear Algebra')
Average_GPAs_of_Major_category('MTH',"320", 'Analysis I')

Average_GPAs_of_Major_category('MTH',"310", 'Abstract Algebra I')
Average_GPAs_of_Major_category('MTH',"340", 'Ordinary Differential Equations')
# Out:
#  GPA's for Majors in MTH 132         Calculus 1
# Education             | GPA: 2.5842 | Sample Size: 582
# Engineering           | GPA: 2.5264 | Sample Size: 9994
# Lyman Briggs          | GPA: 2.2266 | Sample Size: 278
# No Preference         | GPA: 2.5704 | Sample Size: 1904
# Other Major           | GPA: 3.4500 | Sample Size: 20
# Other STEM            | GPA: 2.4859 | Sample Size: 10988
# Physics/Astrophysics  | GPA: 2.2546 | Sample Size: 436
# non STEM              | GPA: 2.3125 | Sample Size: 3136
# Overall               | GPA: 2.4660 | Sample Size: 27338
#
#  GPA's for Majors in LB 118         LB Calculus I
# Education             | GPA: 2.0000 | Sample Size: 2
# Engineering           | GPA: 3.5000 | Sample Size: 12
# Lyman Briggs          | GPA: 3.2041 | Sample Size: 2710
# No Preference         | GPA: 2.1667 | Sample Size: 12
# Other STEM            | GPA: 3.0511 | Sample Size: 842
# Physics/Astrophysics  | GPA: 3.7000 | Sample Size: 10
# ...

# %% [markdown]
# Now that I have this I am going to dig into the switching of majors out of phy/astor using the demographics list as well, first focusing on the people who switched out of astrophysics and physics.
