# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

pd.options.display.max_columns = 50

# %%
classes_1 = pd.read_excel('Classes_FS01-US16_1.xlsx')

# %%
classes_2 = pd.read_excel('Classes_FS01-US16_2.xlsx')

# %%
df_classes_all = pd.concat([classes_1, classes_2], ignore_index=True)
df_classes_all
# Out:
#                                placeholderID  term_seq_id term_code subj_code  \
# 0       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1014      FS01       PHY
# 1       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       MTH
# 2       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       PHY
# 3       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       PHY
# 4       592FB87B-B37F-476D-B7F0-0001F057D6A6         1014      FS01       MTH
# 5       9C41EAAC-FC57-42F9-B53F-000201BE35C3         1054      FS05       MTH
# 6       9C41EAAC-FC57-42F9-B53F-000201BE35C3         1056      SS06       MTH
# 7       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1054      FS05       MTH
# 8       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1064      FS06       MTH
# 9       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1076      SS08       PHY
# 10      7AED7EC2-ED7F-4FE1-8270-000209CBA389         1084      FS08       PHY
# ...

# %%
phy_cc_list = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] in phy_cc_list:
            continue
        else:
            phy_cc_list.append(df_classes_all['crse_code'][i])

# %%
phy_cc_list.sort()

# %%
phy_cc_list
# Out:
# ['101',
#  '102',
#  '170',
#  '181B',
#  '182B',
#  '183',
#  '183A',
#  '183B',
#  '184',
#  '184A',
#  '184B',
#  '191',
#  '192',
#  '193H',
#  '201',
#  '205',
#  '213H',
#  '215',
#  '215B',
#  '231',
#  '231B',
#  '231C',
#  '232',
#  '232B',
#  '232C',
#  '233B',
#  '234B',
#  '251',
#  '252',
#  '294H',
#  '301',
#  '305',
#  '321',
#  '351B',
#  '357B',
#  '390',
#  '405',
#  '410',
#  '415',
#  '422',
#  '425B',
#  '431',
#  '440',
#  '451',
#  '471',
#  '472',
#  '480',
#  '481',
#  '482',
#  '490',
#  '491',
#  '492',
#  '493',
#  '802',
#  '803',
#  '810',
#  '820',
#  '831',
#  '832',
#  '841',
#  '842',
#  '851',
#  '852',
#  '853',
#  '854',
#  '855',
#  '861',
#  '871',
#  '891',
#  '901',
#  '905',
#  '911',
#  '912',
#  '913',
#  '914',
#  '950',
#  '955',
#  '959',
#  '962',
#  '963',
#  '971',
#  '973',
#  '982',
#  '983',
#  'GCG',
#  'GCU']

# %%
len(phy_cc_list)
# Out:
# 86

# %% [markdown]
# ### PHY410

# %%
count_phy410 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '410':
            count_phy410 += 1
            
count_phy410
# Out:
# 657

# %%
df_phy410 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '410')]
df_phy410 = df_phy410.reset_index(drop=True)
df_phy410 = df_phy410.drop_duplicates(subset='placeholderID', keep='last')
df_phy410 = df_phy410.reset_index(drop=True)
df_phy410
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    8AB50F5A-6467-43B0-818C-00215CA7A175         1096      SS10       PHY
# 1    83F2F832-0F1A-4F4F-B73A-0031C962795C         1076      SS08       PHY
# 2    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1066      SS07       PHY
# 3    4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1146      SS15       PHY
# 4    D071B6F5-D901-47CD-B63E-02357DDB88FD         1056      SS06       PHY
# 5    079A93F5-2652-4EB8-AF3B-03CC287F0621         1086      SS09       PHY
# 6    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1056      SS06       PHY
# 7    70DF2CC3-E347-403F-8191-057EB097D566         1146      SS15       PHY
# 8    D43593E9-91AE-4F49-BE30-067283FF0A1F         1096      SS10       PHY
# 9    89DEF1E2-27B3-48A2-BF28-067D20E61342         1106      SS11       PHY
# 10   E6C7F8DC-6795-4BF3-B3C0-069BF7BB386D         1036      SS04       PHY
# ...

# %%
pd.value_counts(df_phy410['major_type'])
# Out:
# Physics/Astrophysics    550
# Other STEM               34
# Lyman Briggs             33
# Engineering              15
# non STEM                  4
# Other Major               2
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY415

# %%
count_phy415 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '415':
            count_phy415 += 1
            
count_phy415
# Out:
# 84

# %%
df_phy415 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '415')]
df_phy415 = df_phy415.reset_index(drop=True)
df_phy415 = df_phy415.drop_duplicates(subset='placeholderID', keep='last')
df_phy415 = df_phy415.reset_index(drop=True)
df_phy415
# Out:
#                            placeholderID  term_seq_id term_code subj_code  \
# 0   E3D03F30-1DC3-42CB-A0E1-02C36D876838         1164      FS16       PHY
# 1   630B3D27-B564-4321-BAD9-044D48AC0DA7         1164      FS16       PHY
# 2   025984B7-6624-49BC-8F26-0A3ED5006308         1154      FS15       PHY
# 3   CEABF562-77EB-432C-90E2-0E2F037434A3         1164      FS16       PHY
# 4   6EF1B8A7-7E47-4317-89BD-10EF91E548F6         1164      FS16       PHY
# 5   E081A374-9680-412A-A8C7-12DC140AC322         1154      FS15       PHY
# 6   B7C6C98A-22E3-455C-ADB2-161FD263F2D3         1164      FS16       PHY
# 7   3D43D147-D67F-430C-A3A1-1AB642F7F2B2         1066      SS07       PHY
# 8   4A0A7982-A5CE-442F-AD47-1FE19FE771E0         1066      SS07       PHY
# 9   B67370B7-AF1A-4CC7-918F-223188363021         1154      FS15       PHY
# 10  563FA5D4-6528-4E27-96D1-274523983887         1144      FS14       PHY
# 11  F943DE46-BC29-4484-BF25-2B9161B80F54         1144      FS14       PHY
# ...

# %%
pd.value_counts(df_phy415['major_type'])
# Out:
# Physics/Astrophysics    71
# Other STEM               6
# Lyman Briggs             3
# Education                2
# Other Major              1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY422

# %%
count_phy422 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '422':
            count_phy422 += 1
            
count_phy422
# Out:
# 163

# %%
df_phy422 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '422')]
df_phy422 = df_phy422.reset_index(drop=True)
df_phy422 = df_phy422.drop_duplicates(subset='placeholderID', keep='last')
df_phy422 = df_phy422.reset_index(drop=True)
df_phy422
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1064      FS06       PHY
# 1    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1054      FS05       PHY
# 2    D43593E9-91AE-4F49-BE30-067283FF0A1F         1104      FS10       PHY
# 3    AA09DDB0-35DE-43D1-A45D-0700DD5BB713         1124      FS12       PHY
# 4    819CEAE2-45C0-4BC6-9F88-0A79E3493131         1084      FS08       PHY
# 5    0116307D-7A53-47B4-AF27-0AAE15476E94         1074      FS07       PHY
# 6    44EBE45B-FB88-4D67-94DB-0D078654005C         1094      FS09       PHY
# 7    162B3917-8105-4520-B9FE-12CFD6D250E1         1154      FS15       PHY
# 8    E081A374-9680-412A-A8C7-12DC140AC322         1144      FS14       PHY
# 9    A37CE049-55FC-40F8-A4AB-16FA928D95C7         1134      FS13       PHY
# 10   278A69D5-95D0-4DF3-AFCA-19AFB6CD01DF         1054      FS05       PHY
# ...

# %%
pd.value_counts(df_phy422['major_type'])
# Out:
# Physics/Astrophysics    142
# Lyman Briggs             11
# Other STEM                6
# Engineering               1
# non STEM                  1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY431

# %%
count_phy431 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '431':
            count_phy431 += 1
            
count_phy431
# Out:
# 320

# %%
df_phy431 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '431')]
df_phy431 = df_phy431.reset_index(drop=True)
df_phy431 = df_phy431.drop_duplicates(subset='placeholderID', keep='last')
df_phy431 = df_phy431.reset_index(drop=True)
df_phy431
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    83F2F832-0F1A-4F4F-B73A-0031C962795C         1074      FS07       PHY
# 1    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1064      FS06       PHY
# 2    200D80F1-AF5D-485E-8509-033337DD56C7         1034      FS03       PHY
# 3    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1054      FS05       PHY
# 4    6756BE26-7C7E-4DB4-93F1-078BD5934BAD         1014      FS01       PHY
# 5    52F8C168-97EE-40EF-AFB3-086DC7A7F65D         1044      FS04       PHY
# 6    025984B7-6624-49BC-8F26-0A3ED5006308         1154      FS15       PHY
# 7    819CEAE2-45C0-4BC6-9F88-0A79E3493131         1084      FS08       PHY
# 8    4E5C40C2-BC5C-4163-8AD1-0ACA1EC3ED7F         1124      FS12       PHY
# 9    155F28D4-F098-45E8-BA1A-0B6CB761B738         1124      FS12       PHY
# 10   D752010F-8453-40DF-B58D-0D2E61942DF3         1094      FS09       PHY
# ...

# %%
pd.value_counts(df_phy431['major_type'])
# Out:
# Physics/Astrophysics    193
# Other STEM              103
# Lyman Briggs             15
# Engineering               4
# non STEM                  2
# Education                 1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY440

# %%
count_phy440 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '440':
            count_phy440 += 1
            
count_phy440
# Out:
# 632

# %%
df_phy440 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '440')]
df_phy440 = df_phy440.reset_index(drop=True)
df_phy440 = df_phy440.drop_duplicates(subset='placeholderID', keep='last')
df_phy440 = df_phy440.reset_index(drop=True)
df_phy440
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    8AB50F5A-6467-43B0-818C-00215CA7A175         1094      FS09       PHY
# 1    83F2F832-0F1A-4F4F-B73A-0031C962795C         1066      SS07       PHY
# 2    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1066      SS07       PHY
# 3    D071B6F5-D901-47CD-B63E-02357DDB88FD         1056      SS06       PHY
# 4    200D80F1-AF5D-485E-8509-033337DD56C7         1036      SS04       PHY
# 5    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1056      SS06       PHY
# 6    70DF2CC3-E347-403F-8191-057EB097D566         1144      FS14       PHY
# 7    D43593E9-91AE-4F49-BE30-067283FF0A1F         1094      FS09       PHY
# 8    89DEF1E2-27B3-48A2-BF28-067D20E61342         1104      FS10       PHY
# 9    AA09DDB0-35DE-43D1-A45D-0700DD5BB713         1134      FS13       PHY
# 10   391E7412-7679-4342-AAAC-075463B04D74         1096      SS10       PHY
# ...

# %%
pd.value_counts(df_phy440['major_type'])
# Out:
# Physics/Astrophysics    453
# Other STEM              117
# Lyman Briggs             21
# Engineering              14
# non STEM                  4
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY451

# %%
count_phy451 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '451':
            count_phy451 += 1
            
count_phy451
# Out:
# 445

# %%
df_phy451 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '451')]
df_phy451 = df_phy451.reset_index(drop=True)
df_phy451 = df_phy451.drop_duplicates(subset='placeholderID', keep='last')
df_phy451 = df_phy451.reset_index(drop=True)
df_phy451
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    8AB50F5A-6467-43B0-818C-00215CA7A175         1096      SS10       PHY
# 1    83F2F832-0F1A-4F4F-B73A-0031C962795C         1074      FS07       PHY
# 2    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1074      FS07       PHY
# 3    D071B6F5-D901-47CD-B63E-02357DDB88FD         1064      FS06       PHY
# 4    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1066      SS07       PHY
# 5    70DF2CC3-E347-403F-8191-057EB097D566         1146      SS15       PHY
# 6    D43593E9-91AE-4F49-BE30-067283FF0A1F         1104      FS10       PHY
# 7    AA09DDB0-35DE-43D1-A45D-0700DD5BB713         1136      SS14       PHY
# 8    6756BE26-7C7E-4DB4-93F1-078BD5934BAD         1014      FS01       PHY
# 9    52F8C168-97EE-40EF-AFB3-086DC7A7F65D         1056      SS06       PHY
# 10   025984B7-6624-49BC-8F26-0A3ED5006308         1156      SS16       PHY
# ...

# %%
pd.value_counts(df_phy451['major_type'])
# Out:
# Physics/Astrophysics    395
# Other STEM               28
# Engineering               9
# Lyman Briggs              7
# Other Major               2
# non STEM                  1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY471

# %%
count_phy471 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '471':
            count_phy471 += 1
            
count_phy471
# Out:
# 793

# %%
df_phy471 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '471')]
df_phy471 = df_phy471.reset_index(drop=True)
df_phy471 = df_phy471.drop_duplicates(subset='placeholderID', keep='last')
df_phy471 = df_phy471.reset_index(drop=True)
df_phy471
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    83F2F832-0F1A-4F4F-B73A-0031C962795C         1064      FS06       PHY
# 1    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1064      FS06       PHY
# 2    4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1144      FS14       PHY
# 3    E3D03F30-1DC3-42CB-A0E1-02C36D876838         1164      FS16       PHY
# 4    079A93F5-2652-4EB8-AF3B-03CC287F0621         1074      FS07       PHY
# 5    630B3D27-B564-4321-BAD9-044D48AC0DA7         1164      FS16       PHY
# 6    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1054      FS05       PHY
# 7    70DF2CC3-E347-403F-8191-057EB097D566         1144      FS14       PHY
# 8    D43593E9-91AE-4F49-BE30-067283FF0A1F         1094      FS09       PHY
# 9    89DEF1E2-27B3-48A2-BF28-067D20E61342         1104      FS10       PHY
# 10   E6C7F8DC-6795-4BF3-B3C0-069BF7BB386D         1034      FS03       PHY
# ...

# %%
pd.value_counts(df_phy471['major_type'])
# Out:
# Physics/Astrophysics    617
# Other STEM               75
# Lyman Briggs             41
# Engineering              22
# non STEM                  7
# Other Major               3
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY472

# %%
count_phy472 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '472':
            count_phy472 += 1
        
count_phy472
# Out:
# 318

# %%
df_phy472 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '472')]
df_phy472 = df_phy472.reset_index(drop=True)
df_phy472 = df_phy472.drop_duplicates(subset='placeholderID', keep='last')
df_phy472 = df_phy472.reset_index(drop=True)
df_phy472
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    83F2F832-0F1A-4F4F-B73A-0031C962795C         1066      SS07       PHY
# 1    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1066      SS07       PHY
# 2    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1056      SS06       PHY
# 3    89DEF1E2-27B3-48A2-BF28-067D20E61342         1106      SS11       PHY
# 4    E6C7F8DC-6795-4BF3-B3C0-069BF7BB386D         1036      SS04       PHY
# 5    AA09DDB0-35DE-43D1-A45D-0700DD5BB713         1116      SS12       PHY
# 6    6756BE26-7C7E-4DB4-93F1-078BD5934BAD         1016      SS02       PHY
# 7    819CEAE2-45C0-4BC6-9F88-0A79E3493131         1086      SS09       PHY
# 8    0116307D-7A53-47B4-AF27-0AAE15476E94         1066      SS07       PHY
# 9    83BB3A0D-7E53-4FC5-9139-0C9072AE0626         1016      SS02       PHY
# 10   44EBE45B-FB88-4D67-94DB-0D078654005C         1106      SS11       PHY
# ...

# %%
pd.value_counts(df_phy472['major_type'])
# Out:
# Physics/Astrophysics    271
# Other STEM               20
# Lyman Briggs             17
# Engineering               5
# non STEM                  1
# Other Major               1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY481

# %%
count_phy481 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '481':
            count_phy481 += 1
            
count_phy481
# Out:
# 735

# %%
df_phy481 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '481')]
df_phy481 = df_phy481.reset_index(drop=True)
df_phy481 = df_phy481.drop_duplicates(subset='placeholderID', keep='last')
df_phy481 = df_phy481.reset_index(drop=True)
df_phy481
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    8AB50F5A-6467-43B0-818C-00215CA7A175         1084      FS08       PHY
# 1    83F2F832-0F1A-4F4F-B73A-0031C962795C         1064      FS06       PHY
# 2    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1064      FS06       PHY
# 3    4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1154      FS15       PHY
# 4    E3D03F30-1DC3-42CB-A0E1-02C36D876838         1164      FS16       PHY
# 5    079A93F5-2652-4EB8-AF3B-03CC287F0621         1084      FS08       PHY
# 6    630B3D27-B564-4321-BAD9-044D48AC0DA7         1164      FS16       PHY
# 7    D12100AD-C82F-488E-9A36-04EF37B34108         1054      FS05       PHY
# 8    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1064      FS06       PHY
# 9    70DF2CC3-E347-403F-8191-057EB097D566         1154      FS15       PHY
# 10   D43593E9-91AE-4F49-BE30-067283FF0A1F         1104      FS10       PHY
# ...

# %%
pd.value_counts(df_phy481['major_type'])
# Out:
# Physics/Astrophysics    575
# Other STEM               64
# Lyman Briggs             32
# Engineering              16
# non STEM                  5
# Other Major               1
# Education                 1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY482

# %%
count_phy482 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '482':
            count_phy482 += 1
            
count_phy482
# Out:
# 179

# %%
df_phy482 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '482')]
df_phy482 = df_phy482.reset_index(drop=True)
df_phy482 = df_phy482.drop_duplicates(subset='placeholderID', keep='last')
df_phy482 = df_phy482.reset_index(drop=True)
df_phy482
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    8AB50F5A-6467-43B0-818C-00215CA7A175         1086      SS09       PHY
# 1    83F2F832-0F1A-4F4F-B73A-0031C962795C         1066      SS07       PHY
# 2    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1076      SS08       PHY
# 3    89DEF1E2-27B3-48A2-BF28-067D20E61342         1116      SS12       PHY
# 4    AA09DDB0-35DE-43D1-A45D-0700DD5BB713         1126      SS13       PHY
# 5    6756BE26-7C7E-4DB4-93F1-078BD5934BAD         1016      SS02       PHY
# 6    175ADA8B-E11F-4CA7-8902-08CA83758049         1156      SS16       PHY
# 7    819CEAE2-45C0-4BC6-9F88-0A79E3493131         1086      SS09       PHY
# 8    0116307D-7A53-47B4-AF27-0AAE15476E94         1076      SS08       PHY
# 9    83BB3A0D-7E53-4FC5-9139-0C9072AE0626         1016      SS02       PHY
# 10   44EBE45B-FB88-4D67-94DB-0D078654005C         1106      SS11       PHY
# ...

# %%
pd.value_counts(df_phy482['major_type'])
# Out:
# Physics/Astrophysics    159
# Other STEM               10
# Lyman Briggs              6
# Engineering               3
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY480

# %%
count_phy480 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '480':
            count_phy480 += 1
            
count_phy480
# Out:
# 93

# %%
df_phy480 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '480')]
df_phy480 = df_phy480.reset_index(drop=True)
df_phy480 = df_phy480.drop_duplicates(subset='placeholderID', keep='last')
df_phy480 = df_phy480.reset_index(drop=True)
df_phy480
# Out:
#                            placeholderID  term_seq_id term_code subj_code  \
# 0   11F8C2B2-8913-46A7-89EE-01A651EED9C6         1076      SS08       PHY
# 1   89DEF1E2-27B3-48A2-BF28-067D20E61342         1096      SS10       PHY
# 2   AA09DDB0-35DE-43D1-A45D-0700DD5BB713         1126      SS13       PHY
# 3   0116307D-7A53-47B4-AF27-0AAE15476E94         1076      SS08       PHY
# 4   44EBE45B-FB88-4D67-94DB-0D078654005C         1096      SS10       PHY
# 5   E081A374-9680-412A-A8C7-12DC140AC322         1156      SS16       PHY
# 6   F772E90C-6018-43B2-8FD9-147B2351C63E         1116      SS12       PHY
# 7   02CD60A9-B41F-4AA8-9AF5-176F1926D03C         1106      SS11       PHY
# 8   52F0C7BB-7431-445A-A787-26DCD38E1757         1136      SS14       PHY
# 9   DA5ED911-55FB-4488-9ED1-279A1BCA10DF         1076      SS08       PHY
# 10  57C1EF32-9154-4E31-9E23-2A8385188CE0         1046      SS05       PHY
# 11  63901B4D-440D-4775-91C8-2C8FFBCE76DC         1026      SS03       PHY
# ...

# %%
pd.value_counts(df_phy480['major_type'])
# Out:
# Physics/Astrophysics    80
# Other STEM              10
# Engineering              3
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY490

# %%
count_phy490 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '490':
            count_phy490 += 1
            
count_phy490
# Out:
# 63

# %%
df_phy490 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '490')]
df_phy490 = df_phy490.reset_index(drop=True)
df_phy490 = df_phy490.drop_duplicates(subset='placeholderID', keep='last')
df_phy490 = df_phy490.reset_index(drop=True)
df_phy490
# Out:
#                            placeholderID  term_seq_id term_code subj_code  \
# 0   8AB50F5A-6467-43B0-818C-00215CA7A175         1094      FS09       PHY
# 1   819CEAE2-45C0-4BC6-9F88-0A79E3493131         1096      SS10       PHY
# 2   02CD60A9-B41F-4AA8-9AF5-176F1926D03C         1102      US10       PHY
# 3   713E52C0-CDA1-40EF-A0E6-187A568C6389         1036      SS04       PHY
# 4   DF34B147-DA33-48B3-843C-2FCE504950D5         1122      US12       PHY
# 5   90256AB2-0A2D-4451-899A-31AC82A9A801         1056      SS06       PHY
# 6   04D0CA5C-2639-4983-9169-36010CC6DD0D         1114      FS11       PHY
# 7   9C6F1D3B-7030-40C0-BA48-39F36E4A55DC         1106      SS11       PHY
# 8   FED96202-8C33-4CCD-817D-4373DDDD94A1         1134      FS13       PHY
# 9   B0FF0A28-7CA6-45D2-9DCB-44D7636D7A3F         1154      FS15       PHY
# 10  53EC533A-FF0B-42F8-81B0-5092701845DC         1104      FS10       PHY
# 11  9FAB53F6-93D8-4D89-AB28-5D5D7C6C2AF0         1054      FS05       PHY
# ...

# %%
pd.value_counts(df_phy490['major_type'])
# Out:
# Physics/Astrophysics    36
# Other STEM               1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY491

# %%
count_phy491 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '491':
            count_phy491 += 1
            
count_phy491
# Out:
# 340

# %%
df_phy491 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '491')]
df_phy491 = df_phy491.reset_index(drop=True)
df_phy491 = df_phy491.drop_duplicates(subset='placeholderID', keep='last')
df_phy491 = df_phy491.reset_index(drop=True)
df_phy491
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    8AB50F5A-6467-43B0-818C-00215CA7A175         1094      FS09       PHY
# 1    83F2F832-0F1A-4F4F-B73A-0031C962795C         1074      FS07       PHY
# 2    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1074      FS07       PHY
# 3    D071B6F5-D901-47CD-B63E-02357DDB88FD         1064      FS06       PHY
# 4    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1064      FS06       PHY
# 5    70DF2CC3-E347-403F-8191-057EB097D566         1154      FS15       PHY
# 6    D43593E9-91AE-4F49-BE30-067283FF0A1F         1104      FS10       PHY
# 7    6756BE26-7C7E-4DB4-93F1-078BD5934BAD         1014      FS01       PHY
# 8    52F8C168-97EE-40EF-AFB3-086DC7A7F65D         1064      FS06       PHY
# 9    0116307D-7A53-47B4-AF27-0AAE15476E94         1084      FS08       PHY
# 10   44EBE45B-FB88-4D67-94DB-0D078654005C         1104      FS10       PHY
# ...

# %%
pd.value_counts(df_phy491['major_type'])
# Out:
# Physics/Astrophysics    308
# Other STEM               15
# Engineering               6
# Lyman Briggs              4
# Other Major               1
# non STEM                  1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY492

# %%
count_phy492 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '492':
            count_phy492 += 1
            
count_phy492
# Out:
# 431

# %%
df_phy492 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '492')]
df_phy492 = df_phy492.reset_index(drop=True)
df_phy492 = df_phy492.drop_duplicates(subset='placeholderID', keep='last')
df_phy492 = df_phy492.reset_index(drop=True)
df_phy492
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    83F2F832-0F1A-4F4F-B73A-0031C962795C         1076      SS08       PHY
# 1    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1076      SS08       PHY
# 2    D071B6F5-D901-47CD-B63E-02357DDB88FD         1056      SS06       PHY
# 3    EBB6CC53-D524-4E0B-85D4-050BC8679B93         1066      SS07       PHY
# 4    70DF2CC3-E347-403F-8191-057EB097D566         1156      SS16       PHY
# 5    D43593E9-91AE-4F49-BE30-067283FF0A1F         1096      SS10       PHY
# 6    E6C7F8DC-6795-4BF3-B3C0-069BF7BB386D         1046      SS05       PHY
# 7    AA09DDB0-35DE-43D1-A45D-0700DD5BB713         1136      SS14       PHY
# 8    391E7412-7679-4342-AAAC-075463B04D74         1106      SS11       PHY
# 9    6756BE26-7C7E-4DB4-93F1-078BD5934BAD         1016      SS02       PHY
# 10   52F8C168-97EE-40EF-AFB3-086DC7A7F65D         1056      SS06       PHY
# ...

# %%
pd.value_counts(df_phy492['major_type'])
# Out:
# Physics/Astrophysics    386
# Other STEM               24
# Lyman Briggs              8
# Engineering               6
# Other Major               1
# non STEM                  1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY493

# %%
count_phy493 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '493':
            count_phy493 += 1
            
count_phy493
# Out:
# 56

# %%
df_phy493 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '493')]
df_phy493 = df_phy493.reset_index(drop=True)
df_phy493 = df_phy493.drop_duplicates(subset='placeholderID', keep='last')
df_phy493 = df_phy493.reset_index(drop=True)
df_phy493
# Out:
#                            placeholderID  term_seq_id term_code subj_code  \
# 0   4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1146      SS15       PHY
# 1   025984B7-6624-49BC-8F26-0A3ED5006308         1156      SS16       PHY
# 2   162B3917-8105-4520-B9FE-12CFD6D250E1         1146      SS15       PHY
# 3   E081A374-9680-412A-A8C7-12DC140AC322         1146      SS15       PHY
# 4   A37CE049-55FC-40F8-A4AB-16FA928D95C7         1146      SS15       PHY
# 5   B8192FCC-7620-480D-8B35-1A97F42C2968         1156      SS16       PHY
# 6   563FA5D4-6528-4E27-96D1-274523983887         1146      SS15       PHY
# 7   7E7D4135-C029-4C40-BB9C-294A94F8E098         1156      SS16       PHY
# 8   F943DE46-BC29-4484-BF25-2B9161B80F54         1146      SS15       PHY
# 9   C6F0EA31-C9E3-4F83-B302-31A2300A5F31         1156      SS16       PHY
# 10  200F4487-1831-4750-BE6A-380A9AE656D5         1146      SS15       PHY
# 11  17302CBC-7762-4F91-B5ED-397DABD2EF42         1156      SS16       PHY
# ...

# %%
pd.value_counts(df_phy493['major_type'])
# Out:
# Physics/Astrophysics    53
# Other STEM               3
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY425B

# %%
count_phy425b = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '425B':
            count_phy425b += 1
            
count_phy425b
# Out:
# 3

# %%
df_phy425b = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '425B')]
df_phy425b = df_phy425b.reset_index(drop=True)
df_phy425b = df_phy425b.drop_duplicates(subset='placeholderID', keep='last')
df_phy425b = df_phy425b.reset_index(drop=True)
df_phy425b
# Out:
#                           placeholderID  term_seq_id term_code subj_code  \
# 0  DA5ED911-55FB-4488-9ED1-279A1BCA10DF         1056      SS06       PHY
# 1  83A63A7B-DC8B-49CE-B83F-6A3553F142DA         1032      US03       PHY
# 2  3B560CEE-588F-4FF6-80E0-E0EDF0B2558E         1032      US03       PHY
#
#   crse_code  sctn_code grade_code repeat_status_flag  major_code  \
# 0      425B        NaN          T                NaN      3842.0
# 1      425B        1.0        1.0                         2337.0
# 2      425B        1.0        4.0                         2337.0
#
#            major_name                       dept_name     college_name  \
# 0            Physics                Physics-Astronomy  Natural Science
# 1   Computer Science   Computer Science & Engineering      Engineering
# 2   Computer Science   Computer Science & Engineering      Engineering
#
#              major_type
# 0  Physics/Astrophysics
# 1            Other STEM
# 2            Other STEM

# %%
pd.value_counts(df_phy425b['major_type'])
# Out:
# Other STEM              2
# Physics/Astrophysics    1
# Name: major_type, dtype: int64

# %% [markdown]
# ### PHY405

# %%
count_phy405 = 0
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '405':
            count_phy405 += 1
            
count_phy405
# Out:
# 80

# %%
df_phy405 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '405')]
df_phy405 = df_phy405.reset_index(drop=True)
df_phy405 = df_phy405.drop_duplicates(subset='placeholderID', keep='last')
df_phy405 = df_phy405.reset_index(drop=True)
df_phy405
# Out:
#                            placeholderID  term_seq_id term_code subj_code  \
# 0   8AB50F5A-6467-43B0-818C-00215CA7A175         1092      US09       PHY
# 1   6756BE26-7C7E-4DB4-93F1-078BD5934BAD         1016      SS02       PHY
# 2   ADBD0832-8B03-495A-BC59-1043EB342837         1106      SS11       PHY
# 3   2CB63F01-1159-4C93-A577-156822510B8C         1094      FS09       PHY
# 4   EDB20CE5-D08F-49BC-9F99-18824904BED9         1094      FS09       PHY
# 5   B8192FCC-7620-480D-8B35-1A97F42C2968         1156      SS16       PHY
# 6   3D43D147-D67F-430C-A3A1-1AB642F7F2B2         1086      SS09       PHY
# 7   A0FAE4AE-5F69-4F0E-BF6D-1F5A2863D825         1052      US05       PHY
# 8   54B344AE-75FE-4C8C-99DA-2136B594C3CD         1082      US08       PHY
# 9   AFCD8B50-1098-4721-BDC5-21A8F9860CC2         1094      FS09       PHY
# 10  B67370B7-AF1A-4CC7-918F-223188363021         1156      SS16       PHY
# 11  66B2D2B2-A252-45A6-BDB2-261AA8003FF4         1084      FS08       PHY
# ...

# %%
pd.value_counts(df_phy405['major_type'])
# Out:
# Physics/Astrophysics    61
# Other STEM               9
# non STEM                 3
# Engineering              1
# Name: major_type, dtype: int64

# %% [markdown]
# Account for students that retake courses, limit so that the only course is the last time the course is taken.

# %%
stu_phy405 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '405':
            if df_classes_all['placeholderID'][i] in stu_phy405:
                continue
            else:
                stu_phy405.append(df_classes_all['placeholderID'][i])

# %%
len(stu_phy405)
# Out:
# 74

# %%
stu_phy410 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '410':
            if df_classes_all['placeholderID'][i] in stu_phy410:
                continue
            else:
                stu_phy410.append(df_classes_all['placeholderID'][i])
                
len(stu_phy410)
# Out:
# 638

# %%
stu_phy415 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '415':
            if df_classes_all['placeholderID'][i] in stu_phy415:
                continue
            else:
                stu_phy415.append(df_classes_all['placeholderID'][i])
                
len(stu_phy415)
# Out:
# 83

# %%
stu_phy422 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '422':
            if df_classes_all['placeholderID'][i] in stu_phy422:
                continue
            else:
                stu_phy422.append(df_classes_all['placeholderID'][i])
                
len(stu_phy422)
# Out:
# 161

# %%
stu_phy425b = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '425B':
            if df_classes_all['placeholderID'][i] in stu_phy425b:
                continue
            else:
                stu_phy425b.append(df_classes_all['placeholderID'][i])
                
len(stu_phy425b)
# Out:
# 3

# %%
stu_phy431 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '431':
            if df_classes_all['placeholderID'][i] in stu_phy431:
                continue
            else:
                stu_phy431.append(df_classes_all['placeholderID'][i])
                
len(stu_phy431)
# Out:
# 318

# %%
stu_phy440 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '440':
            if df_classes_all['placeholderID'][i] in stu_phy440:
                continue
            else:
                stu_phy440.append(df_classes_all['placeholderID'][i])
                
len(stu_phy440)
# Out:
# 609

# %%
stu_phy451 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '451':
            if df_classes_all['placeholderID'][i] in stu_phy451:
                continue
            else:
                stu_phy451.append(df_classes_all['placeholderID'][i])
                
len(stu_phy451)
# Out:
# 442

# %%
stu_phy471 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '471':
            if df_classes_all['placeholderID'][i] in stu_phy471:
                continue
            else:
                stu_phy471.append(df_classes_all['placeholderID'][i])
                
len(stu_phy471)
# Out:
# 765

# %%
stu_phy472 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '472':
            if df_classes_all['placeholderID'][i] in stu_phy472:
                continue
            else:
                stu_phy472.append(df_classes_all['placeholderID'][i])
                
len(stu_phy472)
# Out:
# 315

# %%
stu_phy480 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '480':
            if df_classes_all['placeholderID'][i] in stu_phy480:
                continue
            else:
                stu_phy480.append(df_classes_all['placeholderID'][i])
                
len(stu_phy480)
# Out:
# 93

# %%
stu_phy481 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '481':
            if df_classes_all['placeholderID'][i] in stu_phy481:
                continue
            else:
                stu_phy481.append(df_classes_all['placeholderID'][i])
                
len(stu_phy481)
# Out:
# 694

# %%
stu_phy482 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '482':
            if df_classes_all['placeholderID'][i] in stu_phy482:
                continue
            else:
                stu_phy482.append(df_classes_all['placeholderID'][i])
                
len(stu_phy482)
# Out:
# 178

# %%
stu_phy490 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '490':
            if df_classes_all['placeholderID'][i] in stu_phy490:
                continue
            else:
                stu_phy490.append(df_classes_all['placeholderID'][i])
                
len(stu_phy490)
# Out:
# 37

# %%
stu_phy491 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '491':
            if df_classes_all['placeholderID'][i] in stu_phy491:
                continue
            else:
                stu_phy491.append(df_classes_all['placeholderID'][i])
                
len(stu_phy491)
# Out:
# 335

# %%
stu_phy492 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '492':
            if df_classes_all['placeholderID'][i] in stu_phy492:
                continue
            else:
                stu_phy492.append(df_classes_all['placeholderID'][i])
                
len(stu_phy492)
# Out:
# 426

# %%
stu_phy493 = []
for i in range(len(df_classes_all)):
    if df_classes_all['subj_code'][i] == 'PHY':
        if df_classes_all['crse_code'][i] == '493':
            if df_classes_all['placeholderID'][i] in stu_phy493:
                continue
            else:
                stu_phy493.append(df_classes_all['placeholderID'][i])
                
len(stu_phy493)
# Out:
# 56

# %%
# find students that took PHY410, PHY471, and PHY481
stu_phy410_471_481 = []
for i in stu_phy410:
    if i in stu_phy471:
        if i in stu_phy481:
            stu_phy410_471_481.append(i)
            
stu_phy410_471_481
# Out:
# ['83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  '11F8C2B2-8913-46A7-89EE-01A651EED9C6',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
#  '079A93F5-2652-4EB8-AF3B-03CC287F0621',
#  'EBB6CC53-D524-4E0B-85D4-050BC8679B93',
#  '70DF2CC3-E347-403F-8191-057EB097D566',
#  'D43593E9-91AE-4F49-BE30-067283FF0A1F',
#  'E6C7F8DC-6795-4BF3-B3C0-069BF7BB386D',
#  'AA09DDB0-35DE-43D1-A45D-0700DD5BB713',
#  '52F8C168-97EE-40EF-AFB3-086DC7A7F65D',
#  '025984B7-6624-49BC-8F26-0A3ED5006308',
#  '819CEAE2-45C0-4BC6-9F88-0A79E3493131',
#  '85AD112B-3731-4885-BB69-0A7E508EF233',
#  '0116307D-7A53-47B4-AF27-0AAE15476E94',
#  '4E5C40C2-BC5C-4163-8AD1-0ACA1EC3ED7F',
#  '155F28D4-F098-45E8-BA1A-0B6CB761B738',
#  '44EBE45B-FB88-4D67-94DB-0D078654005C',
#  'D752010F-8453-40DF-B58D-0D2E61942DF3',
#  'CEABF562-77EB-432C-90E2-0E2F037434A3',
#  '162B3917-8105-4520-B9FE-12CFD6D250E1',
#  'E081A374-9680-412A-A8C7-12DC140AC322',
#  'FAE2F556-6DD4-41F6-9D62-146F7FA2234F',
#  'E483BFA0-0124-4492-8211-14AE41D7A2A8',
# ...

# %%
len(stu_phy410_471_481)
# Out:
# 566

# %%
for i in range(len(df_classes_all)):
    stu = df_classes_all['placeholderID'][i]
    subj = df_classes_all['subj_code'][i]
    crse = df_classes_all['crse_code'][i]
    term = df_classes_all['term_code'][i]
    if stu in stu_phy410_471_481:
        if subj == 'PHY':
            if crse == '410':
                print(stu, subj, crse, term)
        if subj == 'PHY':
            if crse == '471':
                print(stu, subj, crse, term)
        if subj == 'PHY':
            if crse == '481':
                print(stu, subj, crse, term)
# Out:
# 83F2F832-0F1A-4F4F-B73A-0031C962795C PHY 471 FS06
# 83F2F832-0F1A-4F4F-B73A-0031C962795C PHY 481 FS06
# 83F2F832-0F1A-4F4F-B73A-0031C962795C PHY 410 SS08
# 11F8C2B2-8913-46A7-89EE-01A651EED9C6 PHY 471 FS06
# 11F8C2B2-8913-46A7-89EE-01A651EED9C6 PHY 481 FS06
# 11F8C2B2-8913-46A7-89EE-01A651EED9C6 PHY 410 SS07
# 4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9 PHY 471 FS14
# 4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9 PHY 410 SS15
# 4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9 PHY 481 FS15
# 079A93F5-2652-4EB8-AF3B-03CC287F0621 PHY 471 FS07
# 079A93F5-2652-4EB8-AF3B-03CC287F0621 PHY 481 FS08
# 079A93F5-2652-4EB8-AF3B-03CC287F0621 PHY 410 SS09
# EBB6CC53-D524-4E0B-85D4-050BC8679B93 PHY 471 FS05
# EBB6CC53-D524-4E0B-85D4-050BC8679B93 PHY 410 SS06
# EBB6CC53-D524-4E0B-85D4-050BC8679B93 PHY 481 FS06
# 70DF2CC3-E347-403F-8191-057EB097D566 PHY 471 FS14
# 70DF2CC3-E347-403F-8191-057EB097D566 PHY 410 SS15
# 70DF2CC3-E347-403F-8191-057EB097D566 PHY 481 FS15
# D43593E9-91AE-4F49-BE30-067283FF0A1F PHY 471 FS09
# ...

# %%
# add PHY451 to the list
stu_phy410_451_471_481 = []
for i in stu_phy410:
    if i in stu_phy451:
        if i in stu_phy471:
            if i in stu_phy481:
                stu_phy410_451_471_481.append(i)
            
stu_phy410_451_471_481
# Out:
# ['83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  '11F8C2B2-8913-46A7-89EE-01A651EED9C6',
#  'EBB6CC53-D524-4E0B-85D4-050BC8679B93',
#  '70DF2CC3-E347-403F-8191-057EB097D566',
#  'D43593E9-91AE-4F49-BE30-067283FF0A1F',
#  'AA09DDB0-35DE-43D1-A45D-0700DD5BB713',
#  '52F8C168-97EE-40EF-AFB3-086DC7A7F65D',
#  '025984B7-6624-49BC-8F26-0A3ED5006308',
#  '819CEAE2-45C0-4BC6-9F88-0A79E3493131',
#  '0116307D-7A53-47B4-AF27-0AAE15476E94',
#  '4E5C40C2-BC5C-4163-8AD1-0ACA1EC3ED7F',
#  '155F28D4-F098-45E8-BA1A-0B6CB761B738',
#  '44EBE45B-FB88-4D67-94DB-0D078654005C',
#  '162B3917-8105-4520-B9FE-12CFD6D250E1',
#  'E081A374-9680-412A-A8C7-12DC140AC322',
#  'E483BFA0-0124-4492-8211-14AE41D7A2A8',
#  '2CB63F01-1159-4C93-A577-156822510B8C',
#  '039AD888-6EA2-4B9F-9C39-15C8220347A2',
#  '4679FF33-49F5-4472-B4B4-16AAF2CAB877',
#  'A37CE049-55FC-40F8-A4AB-16FA928D95C7',
#  '02CD60A9-B41F-4AA8-9AF5-176F1926D03C',
#  '713E52C0-CDA1-40EF-A0E6-187A568C6389',
#  'EDB20CE5-D08F-49BC-9F99-18824904BED9',
# ...

# %%
len(stu_phy410_451_471_481)
# Out:
# 401
