# %% [markdown]
# In this notebook, I will do something similar to 07-03_extended_class_dataset, but instead of requiring students to have taken every single course in each extended dataset, I only require that the student takes one of the courses. If they take 1 but not the others, they will be listed as 'Did not take(course)'.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

pd.options.display.max_columns = 50

# %%
df_classes_1 = pd.read_excel('Classes_FS01-US16_1.xlsx')
df_classes_1
# Out:
#                                placeholderID  term_seq_id term_code subj_code  \
# 0       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1014      FS01       PHY
# 1       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       MTH
# 2       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       PHY
# 3       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       PHY
# 4       592FB87B-B37F-476D-B7F0-0001F057D6A6         1014      FS01       MTH
# 5       9C41EAAC-FC57-42F9-B53F-000201BE35C3         1054      FS05       MTH
# 6       9C41EAAC-FC57-42F9-B53F-000201BE35C3         1056      SS06       MTH
# 7       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1054      FS05       MTH
# 8       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1064      FS06       MTH
# 9       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1076      SS08       PHY
# 10      7AED7EC2-ED7F-4FE1-8270-000209CBA389         1084      FS08       PHY
# ...

# %%
df_classes_2 = pd.read_excel('Classes_FS01-US16_2.xlsx')
df_classes_2
# Out:
#                                placeholderID  term_seq_id term_code subj_code  \
# 0       054161B5-A668-4A93-9D1F-7F81E15EB01C         1104      FS10       MTH
# 1       054161B5-A668-4A93-9D1F-7F81E15EB01C         1106      SS11       MTH
# 2       054161B5-A668-4A93-9D1F-7F81E15EB01C         1114      FS11       MTH
# 3       054161B5-A668-4A93-9D1F-7F81E15EB01C         1116      SS12       MTH
# 4       054161B5-A668-4A93-9D1F-7F81E15EB01C         1116      SS12       PHY
# 5       054161B5-A668-4A93-9D1F-7F81E15EB01C         1124      FS12       MTH
# 6       054161B5-A668-4A93-9D1F-7F81E15EB01C         1124      FS12       PHY
# 7       054161B5-A668-4A93-9D1F-7F81E15EB01C         1126      SS13       MTH
# 8       054161B5-A668-4A93-9D1F-7F81E15EB01C         1134      FS13       MTH
# 9       054161B5-A668-4A93-9D1F-7F81E15EB01C         1136      SS14       MTH
# 10      E69CC0A8-E21E-4364-AD40-7F82060E3702         1084      FS08       MTH
# ...

# %%
df_classes_all = pd.concat([df_classes_1, df_classes_2], ignore_index=True)
df_classes_all
# Out:
#                                placeholderID  term_seq_id term_code subj_code  \
# 0       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1014      FS01       PHY
# 1       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       MTH
# 2       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       PHY
# 3       97758DD4-7286-4A19-BA6C-00005FE6CFA3         1016      SS02       PHY
# 4       592FB87B-B37F-476D-B7F0-0001F057D6A6         1014      FS01       MTH
# 5       9C41EAAC-FC57-42F9-B53F-000201BE35C3         1054      FS05       MTH
# 6       9C41EAAC-FC57-42F9-B53F-000201BE35C3         1056      SS06       MTH
# 7       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1054      FS05       MTH
# 8       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1064      FS06       MTH
# 9       7AED7EC2-ED7F-4FE1-8270-000209CBA389         1076      SS08       PHY
# 10      7AED7EC2-ED7F-4FE1-8270-000209CBA389         1084      FS08       PHY
# ...

# %%
df_classes_all = df_classes_all[(df_classes_all['grade_code'] != 'T')&(df_classes_all['grade_code'] != 'WV')&(df_classes_all['grade_code'] != 'TWV')&(df_classes_all['grade_code'] != 'P')&(df_classes_all['grade_code'] != 'N')&(df_classes_all['grade_code'] != 'WVR')&(df_classes_all['grade_code'] != 'T1')&(df_classes_all['grade_code'] != 'W')&(df_classes_all['grade_code'] != 'WV1')&(df_classes_all['grade_code'] != 'V')&(df_classes_all['grade_code'] != 'U')&(df_classes_all['grade_code'] != 'I')&(df_classes_all['grade_code'] != ' ')]
df_classes_all = df_classes_all.reset_index(drop=True)
pd.value_counts(df_classes_all['grade_code'].values, sort=True)
# Out:
# 4.0    80945
# 3.0    76399
# 3.5    68839
# 2.5    61429
# 2.0    50745
# 0.0    36014
# 1.5    22865
# 1.0    16505
# dtype: int64

# %%
df_phy183 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '183')|(df_classes_all['crse_code'] == '183A')|(df_classes_all['crse_code'] == '183B')]
df_phy183 = df_phy183.reset_index(drop=True)
df_phy183 = df_phy183.drop_duplicates(subset='placeholderID', keep='last')
df_phy183 = df_phy183.reset_index(drop=True)
df_phy183
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1116      SS12       PHY
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408         1076      SS08       PHY
# 2      576F115D-3565-420F-AAE7-0007266980A5         1044      FS04       PHY
# 3      6D1640CF-6645-4899-9055-00089F24558C         1024      FS02       PHY
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0         1096      SS10       PHY
# 5      7393F06D-4793-444D-AF49-0014F5819E0C         1056      SS06       PHY
# 6      44B51964-1C8D-43D2-815D-00177931EC51         1134      FS13       PHY
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175         1074      FS07       PHY
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06         1042      US04       PHY
# 9      05D5381D-AA75-415C-94AA-00311A192699         1046      SS05       PHY
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1         1014      FS01       PHY
# ...

# %%
pd.value_counts(df_phy183['crse_code'])
# Out:
# 183     15148
# 183B      982
# 183A        1
# Name: crse_code, dtype: int64

# %%
pd.value_counts(df_phy183['major_type'])
# Out:
# Engineering             8975
# Other STEM              5316
# non STEM                 567
# Physics/Astrophysics     545
# Lyman Briggs             465
# No Preference            243
# Education                 17
# Other Major                3
# Name: major_type, dtype: int64

# %%
df_phy184 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '184')|(df_classes_all['crse_code'] == '184A')|(df_classes_all['crse_code'] == '184B')]
df_phy184 = df_phy184.reset_index(drop=True)
df_phy184 = df_phy184.drop_duplicates(subset='placeholderID', keep='last')
df_phy184 = df_phy184.reset_index(drop=True)
df_phy184
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1134      FS13       PHY
# 1      0A9563A9-3C0B-48AA-B8E2-0006E536F36F         1016      SS02       PHY
# 2      576F115D-3565-420F-AAE7-0007266980A5         1046      SS05       PHY
# 3      6D1640CF-6645-4899-9055-00089F24558C         1026      SS03       PHY
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0         1114      FS11       PHY
# 5      7393F06D-4793-444D-AF49-0014F5819E0C         1074      FS07       PHY
# 6      44B51964-1C8D-43D2-815D-00177931EC51         1136      SS14       PHY
# 7      A85B8D33-65D2-4301-AE36-001A401BFF01         1144      FS14       PHY
# 8      8AB50F5A-6467-43B0-818C-00215CA7A175         1082      US08       PHY
# 9      88361B49-55BC-4BE5-942A-0026B54AEB06         1036      SS04       PHY
# 10     05D5381D-AA75-415C-94AA-00311A192699         1052      US05       PHY
# ...

# %%
pd.value_counts(df_phy184['crse_code'])
# Out:
# 184     12659
# 184B     1071
# 184A        1
# Name: crse_code, dtype: int64

# %%
pd.value_counts(df_phy184['major_type'])
# Out:
# Engineering             7987
# Other STEM              4432
# Physics/Astrophysics     742
# non STEM                 265
# Lyman Briggs             253
# No Preference             46
# Education                  6
# Name: major_type, dtype: int64

# %%
phy183_stu = []
for i in range(len(df_phy183)):
    if df_phy183['placeholderID'][i] in phy183_stu:
        continue
    else:
        phy183_stu.append(df_phy183['placeholderID'][i])
        
phy183_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  '1E72FA2E-BAA7-4224-9425-0033CD0BDA55',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '39D7AB4A-40DC-4133-AA5A-00421E7C9263',
#  '111190B4-0FE3-4CE3-B20B-004EC7A4A385',
#  '0B94E3B1-C42F-4825-864B-004FB6E27FCD',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F6B64904-ED07-49ED-843A-00616EA7751A',
# ...

# %%
phy184_stu = []
for i in range(len(df_phy184)):
    if df_phy184['placeholderID'][i] in phy184_stu:
        continue
    else:
        phy184_stu.append(df_phy184['placeholderID'][i])
        
phy184_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '0A9563A9-3C0B-48AA-B8E2-0006E536F36F',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  'A85B8D33-65D2-4301-AE36-001A401BFF01',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '4ECD5846-280F-4672-BFDC-003FDB8076F0',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F0332AAB-A2FB-405D-AE88-006294175189',
#  '1BB808D0-971D-4A46-8379-006D750D3398',
#  '3A666148-2D71-49B5-81ED-007DBB634DDD',
# ...

# %%
ls_phy183_184_stu = []
for i in phy183_stu:
    if i in ls_phy183_184_stu:
        continue
    else:
        ls_phy183_184_stu.append(i)
        
for j in phy184_stu:
    if j in ls_phy183_184_stu:
        continue
    else:
        ls_phy183_184_stu.append(j)

# %%
ls_phy183_184_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  '1E72FA2E-BAA7-4224-9425-0033CD0BDA55',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '39D7AB4A-40DC-4133-AA5A-00421E7C9263',
#  '111190B4-0FE3-4CE3-B20B-004EC7A4A385',
#  '0B94E3B1-C42F-4825-864B-004FB6E27FCD',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F6B64904-ED07-49ED-843A-00616EA7751A',
# ...

# %%
cols = ('placeholderID', 'term_seq_id_183', 'term_code_183', 'grade_code_183', 'repeat_status_flag_183', 'major_code_183', 'major_name_183', 'major_type_183', 'term_seq_id_184', 'term_code_184', 'grade_code_184', 'repeat_status_flag_184', 'major_code_184', 'major_name_184', 'major_type_184')
df_phy183_184 = pd.DataFrame(columns=cols)
df_phy183_184
# Out:
# Empty DataFrame
# Columns: [placeholderID, term_seq_id_183, term_code_183, grade_code_183, repeat_status_flag_183, major_code_183, major_name_183, major_type_183, term_seq_id_184, term_code_184, grade_code_184, repeat_status_flag_184, major_code_184, major_name_184, major_type_184]
# Index: []

# %%
df_phy183_184.set_value(0, 'placeholderID', ls_phy183_184_stu[0])
# Out:
#                           placeholderID term_seq_id_183 term_code_183  \
# 0  3C1C5E03-FA14-4F6A-B0C6-000250988C23             NaN           NaN
#
#   grade_code_183 repeat_status_flag_183 major_code_183 major_name_183  \
# 0            NaN                    NaN            NaN            NaN
#
#   major_type_183 term_seq_id_184 term_code_184 grade_code_184  \
# 0            NaN             NaN           NaN            NaN
#
#   repeat_status_flag_184 major_code_184 major_name_184 major_type_184
# 0                    NaN            NaN            NaN            NaN

# %%
for i in range(len(ls_phy183_184_stu)):
    df_phy183_184.set_value(i, 'placeholderID', ls_phy183_184_stu[i])

# %%
df_phy183_184
# Out:
#                               placeholderID term_seq_id_183 term_code_183  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23             NaN           NaN
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408             NaN           NaN
# 2      576F115D-3565-420F-AAE7-0007266980A5             NaN           NaN
# 3      6D1640CF-6645-4899-9055-00089F24558C             NaN           NaN
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0             NaN           NaN
# 5      7393F06D-4793-444D-AF49-0014F5819E0C             NaN           NaN
# 6      44B51964-1C8D-43D2-815D-00177931EC51             NaN           NaN
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175             NaN           NaN
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06             NaN           NaN
# 9      05D5381D-AA75-415C-94AA-00311A192699             NaN           NaN
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1             NaN           NaN
# 11     690B1653-B55B-405A-9E4F-0032C72511B4             NaN           NaN
# ...

# %%
stu = df_phy183_184['placeholderID'][7]
stu2 = df_phy184.loc[df_phy184['placeholderID'] == stu]
stu_loc = int(df_phy184.index.get_indexer_for((df_phy184[df_phy184['placeholderID'] == stu].index)))
print(stu)
print(stu_loc)
stu2
# Out:
# 8AB50F5A-6467-43B0-818C-00215CA7A175
# 8
#                           placeholderID  term_seq_id term_code subj_code  \
# 8  8AB50F5A-6467-43B0-818C-00215CA7A175         1082      US08       PHY
#
#   crse_code  sctn_code grade_code repeat_status_flag  major_code major_name  \
# 8      184B      730.0        4.0                         3842.0   Physics
#
#            dept_name     college_name            major_type
# 8  Physics-Astronomy  Natural Science  Physics/Astrophysics

# %%
for i in range(len(df_phy183_184)):
    stu = df_phy183_184['placeholderID'][i]
    if stu in phy183_stu:
        stu2 = df_phy183.loc[df_phy183['placeholderID'] == stu]
        stu_loc = int(df_phy183.index.get_indexer_for((df_phy183[df_phy183['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184.set_value(i, 'term_seq_id_183', stu2['term_seq_id'][stu_loc])
                df_phy183_184.set_value(i, 'term_code_183', stu2['term_code'][stu_loc])
                df_phy183_184.set_value(i, 'grade_code_183', stu2['grade_code'][stu_loc])
                df_phy183_184.set_value(i, 'repeat_status_flag_183', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184.set_value(i, 'major_code_183', stu2['major_code'][stu_loc])
                df_phy183_184.set_value(i, 'major_name_183', stu2['major_name'][stu_loc])
                df_phy183_184.set_value(i, 'major_type_183', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184.set_value(i, 'term_seq_id_183', 'DNT PHY183')
        df_phy183_184.set_value(i, 'term_code_183', 'DNT PHY183')
        df_phy183_184.set_value(i, 'grade_code_183', 'DNT PHY183')
        df_phy183_184.set_value(i, 'repeat_status_flag_183', 'DNT PHY183')
        df_phy183_184.set_value(i, 'major_code_183', 'DNT PHY183')
        df_phy183_184.set_value(i, 'major_name_183', 'DNT PHY183')
        df_phy183_184.set_value(i, 'major_type_183', 'DNT PHY183')
        
        
        
    if stu in phy184_stu:
        stu2 = df_phy184.loc[df_phy184['placeholderID'] == stu]
        stu_loc = int(df_phy184.index.get_indexer_for((df_phy184[df_phy184['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184.set_value(i, 'term_seq_id_184', stu2['term_seq_id'][stu_loc])
                df_phy183_184.set_value(i, 'term_code_184', stu2['term_code'][stu_loc])
                df_phy183_184.set_value(i, 'grade_code_184', stu2['grade_code'][stu_loc])
                df_phy183_184.set_value(i, 'repeat_status_flag_184', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184.set_value(i, 'major_code_184', stu2['major_code'][stu_loc])
                df_phy183_184.set_value(i, 'major_name_184', stu2['major_name'][stu_loc])
                df_phy183_184.set_value(i, 'major_type_184', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184.set_value(i, 'term_seq_id_184', 'DNT PHY184')
        df_phy183_184.set_value(i, 'term_code_184', 'DNT PHY184')
        df_phy183_184.set_value(i, 'grade_code_184', 'DNT PHY184')
        df_phy183_184.set_value(i, 'repeat_status_flag_184', 'DNT PHY184')
        df_phy183_184.set_value(i, 'major_code_184', 'DNT PHY184')
        df_phy183_184.set_value(i, 'major_name_184', 'DNT PHY184')
        df_phy183_184.set_value(i, 'major_type_184', 'DNT PHY184')

# %%
df_phy183_184
# Out:
#                               placeholderID term_seq_id_183 term_code_183  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23            1116          SS12
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408            1076          SS08
# 2      576F115D-3565-420F-AAE7-0007266980A5            1044          FS04
# 3      6D1640CF-6645-4899-9055-00089F24558C            1024          FS02
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0            1096          SS10
# 5      7393F06D-4793-444D-AF49-0014F5819E0C            1056          SS06
# 6      44B51964-1C8D-43D2-815D-00177931EC51            1134          FS13
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175            1074          FS07
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06            1042          US04
# 9      05D5381D-AA75-415C-94AA-00311A192699            1046          SS05
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1            1014          FS01
# 11     690B1653-B55B-405A-9E4F-0032C72511B4            1036          SS04
# ...

# %%
pd.value_counts(df_phy183_184['major_type_183'])
# Out:
# Engineering             8975
# Other STEM              5316
# DNT PHY183              2050
# non STEM                 567
# Physics/Astrophysics     545
# Lyman Briggs             465
# No Preference            243
# Education                 17
# Other Major                3
# Name: major_type_183, dtype: int64

# %%
pd.value_counts(df_phy183_184['major_type_184'])
# Out:
# Engineering             7987
# DNT PHY184              4450
# Other STEM              4432
# Physics/Astrophysics     742
# non STEM                 265
# Lyman Briggs             253
# No Preference             46
# Education                  6
# Name: major_type_184, dtype: int64

# %%
from pandas import ExcelWriter
writer = ExcelWriter('Classes_phy183_184_any.xlsx')
df_phy183_184.to_excel(writer, 'Sheet1')
writer.save()

# %% [markdown]
# ### PHY183-->PHY184-->PHY215

# %%
df_phy183 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '183')|(df_classes_all['crse_code'] == '183A')|(df_classes_all['crse_code'] == '183B')]
df_phy183 = df_phy183.reset_index(drop=True)
df_phy183 = df_phy183.drop_duplicates(subset='placeholderID', keep='last')
df_phy183 = df_phy183.reset_index(drop=True)
df_phy183
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1116      SS12       PHY
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408         1076      SS08       PHY
# 2      576F115D-3565-420F-AAE7-0007266980A5         1044      FS04       PHY
# 3      6D1640CF-6645-4899-9055-00089F24558C         1024      FS02       PHY
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0         1096      SS10       PHY
# 5      7393F06D-4793-444D-AF49-0014F5819E0C         1056      SS06       PHY
# 6      44B51964-1C8D-43D2-815D-00177931EC51         1134      FS13       PHY
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175         1074      FS07       PHY
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06         1042      US04       PHY
# 9      05D5381D-AA75-415C-94AA-00311A192699         1046      SS05       PHY
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1         1014      FS01       PHY
# ...

# %%
df_phy184 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '184')|(df_classes_all['crse_code'] == '184A')|(df_classes_all['crse_code'] == '184B')]
df_phy184 = df_phy184.reset_index(drop=True)
df_phy184 = df_phy184.drop_duplicates(subset='placeholderID', keep='last')
df_phy184 = df_phy184.reset_index(drop=True)
df_phy184
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1134      FS13       PHY
# 1      0A9563A9-3C0B-48AA-B8E2-0006E536F36F         1016      SS02       PHY
# 2      576F115D-3565-420F-AAE7-0007266980A5         1046      SS05       PHY
# 3      6D1640CF-6645-4899-9055-00089F24558C         1026      SS03       PHY
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0         1114      FS11       PHY
# 5      7393F06D-4793-444D-AF49-0014F5819E0C         1074      FS07       PHY
# 6      44B51964-1C8D-43D2-815D-00177931EC51         1136      SS14       PHY
# 7      A85B8D33-65D2-4301-AE36-001A401BFF01         1144      FS14       PHY
# 8      8AB50F5A-6467-43B0-818C-00215CA7A175         1082      US08       PHY
# 9      88361B49-55BC-4BE5-942A-0026B54AEB06         1036      SS04       PHY
# 10     05D5381D-AA75-415C-94AA-00311A192699         1052      US05       PHY
# ...

# %%
df_phy215 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '215')|(df_classes_all['crse_code'] == '215B')]
df_phy215 = df_phy215.reset_index(drop=True)
df_phy215 = df_phy215.drop_duplicates(subset='placeholderID', keep='last')
df_phy215 = df_phy215.reset_index(drop=True)
df_phy215
# Out:
#                              placeholderID  term_seq_id term_code subj_code  \
# 0     8AB50F5A-6467-43B0-818C-00215CA7A175         1084      FS08       PHY
# 1     83F2F832-0F1A-4F4F-B73A-0031C962795C         1056      SS06       PHY
# 2     1E193C37-DBD0-4C80-B30F-00AE0B75B3A9         1066      SS07       PHY
# 3     AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF         1036      SS04       PHY
# 4     128348BA-5824-43F5-9D26-0106E6B9A7BD         1086      SS09       PHY
# 5     11F8C2B2-8913-46A7-89EE-01A651EED9C6         1046      SS05       PHY
# 6     7AFA4E6D-8545-481E-8091-01B1545A8084         1144      FS14       PHY
# 7     4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1136      SS14       PHY
# 8     D071B6F5-D901-47CD-B63E-02357DDB88FD         1046      SS05       PHY
# 9     E3D03F30-1DC3-42CB-A0E1-02C36D876838         1154      FS15       PHY
# 10    C4396ED4-8A37-41B6-A1DD-032F43A6192A         1054      FS05       PHY
# ...

# %%
phy183_stu = []
for i in range(len(df_phy183)):
    if df_phy183['placeholderID'][i] in phy183_stu:
        continue
    else:
        phy183_stu.append(df_phy183['placeholderID'][i])
        
phy183_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  '1E72FA2E-BAA7-4224-9425-0033CD0BDA55',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '39D7AB4A-40DC-4133-AA5A-00421E7C9263',
#  '111190B4-0FE3-4CE3-B20B-004EC7A4A385',
#  '0B94E3B1-C42F-4825-864B-004FB6E27FCD',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F6B64904-ED07-49ED-843A-00616EA7751A',
# ...

# %%
phy184_stu = []
for i in range(len(df_phy184)):
    if df_phy184['placeholderID'][i] in phy184_stu:
        continue
    else:
        phy184_stu.append(df_phy184['placeholderID'][i])
        
phy184_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '0A9563A9-3C0B-48AA-B8E2-0006E536F36F',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  'A85B8D33-65D2-4301-AE36-001A401BFF01',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '4ECD5846-280F-4672-BFDC-003FDB8076F0',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F0332AAB-A2FB-405D-AE88-006294175189',
#  '1BB808D0-971D-4A46-8379-006D750D3398',
#  '3A666148-2D71-49B5-81ED-007DBB634DDD',
# ...

# %%
phy215_stu = []
for i in range(len(df_phy215)):
    if df_phy215['placeholderID'][i] in phy215_stu:
        continue
    else:
        phy215_stu.append(df_phy215['placeholderID'][i])
        
phy215_stu
# Out:
# ['8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  '1E193C37-DBD0-4C80-B30F-00AE0B75B3A9',
#  'AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF',
#  '128348BA-5824-43F5-9D26-0106E6B9A7BD',
#  '11F8C2B2-8913-46A7-89EE-01A651EED9C6',
#  '7AFA4E6D-8545-481E-8091-01B1545A8084',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
#  'D071B6F5-D901-47CD-B63E-02357DDB88FD',
#  'E3D03F30-1DC3-42CB-A0E1-02C36D876838',
#  'C4396ED4-8A37-41B6-A1DD-032F43A6192A',
#  '200D80F1-AF5D-485E-8509-033337DD56C7',
#  '079A93F5-2652-4EB8-AF3B-03CC287F0621',
#  '37523C48-3534-4A05-842A-03D274E396FA',
#  'A49DDFD9-D0A4-490C-8A4C-03DA12D0439A',
#  'BE8F33D0-4FD1-44D6-98C3-03EB2B1A7A7C',
#  '630B3D27-B564-4321-BAD9-044D48AC0DA7',
#  'D487A88D-98DF-45E4-8F8D-045C16CC0A12',
#  '688CD527-98FD-485B-90E1-049E6CA8C844',
#  'EF2B5097-2ED0-4D31-A1C5-04DDBC9D7ABB',
#  'D12100AD-C82F-488E-9A36-04EF37B34108',
#  'EBB6CC53-D524-4E0B-85D4-050BC8679B93',
#  '70DF2CC3-E347-403F-8191-057EB097D566',
# ...

# %%
ls_phy183_184_215_stu = []
for i in phy183_stu:
    if i in ls_phy183_184_215_stu:
        continue
    else:
        ls_phy183_184_215_stu.append(i)
        
for j in phy184_stu:
    if j in ls_phy183_184_215_stu:
        continue
    else:
        ls_phy183_184_215_stu.append(j)
        
for k in phy215_stu:
    if k in ls_phy183_184_215_stu:
        continue
    else:
        ls_phy183_184_215_stu.append(k)

# %%
ls_phy183_184_215_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  '1E72FA2E-BAA7-4224-9425-0033CD0BDA55',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '39D7AB4A-40DC-4133-AA5A-00421E7C9263',
#  '111190B4-0FE3-4CE3-B20B-004EC7A4A385',
#  '0B94E3B1-C42F-4825-864B-004FB6E27FCD',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F6B64904-ED07-49ED-843A-00616EA7751A',
# ...

# %%
cols = ('placeholderID', 'term_seq_id_183', 'term_code_183', 'grade_code_183', 'repeat_status_flag_183', 'major_code_183', 'major_name_183', 'major_type_183', 'term_seq_id_184', 'term_code_184', 'grade_code_184', 'repeat_status_flag_184', 'major_code_184', 'major_name_184', 'major_type_184', 'term_seq_id_215', 'term_code_215', 'grade_code_215', 'repeat_status_flag_215', 'major_code_215', 'major_name_215', 'major_type_215')
df_phy183_184_215 = pd.DataFrame(columns=cols)
df_phy183_184_215
# Out:
# Empty DataFrame
# Columns: [placeholderID, term_seq_id_183, term_code_183, grade_code_183, repeat_status_flag_183, major_code_183, major_name_183, major_type_183, term_seq_id_184, term_code_184, grade_code_184, repeat_status_flag_184, major_code_184, major_name_184, major_type_184, term_seq_id_215, term_code_215, grade_code_215, repeat_status_flag_215, major_code_215, major_name_215, major_type_215]
# Index: []

# %%
for i in range(len(ls_phy183_184_215_stu)):
    df_phy183_184_215.set_value(i, 'placeholderID', ls_phy183_184_215_stu[i])

# %%
df_phy183_184_215
# Out:
#                               placeholderID term_seq_id_183 term_code_183  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23             NaN           NaN
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408             NaN           NaN
# 2      576F115D-3565-420F-AAE7-0007266980A5             NaN           NaN
# 3      6D1640CF-6645-4899-9055-00089F24558C             NaN           NaN
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0             NaN           NaN
# 5      7393F06D-4793-444D-AF49-0014F5819E0C             NaN           NaN
# 6      44B51964-1C8D-43D2-815D-00177931EC51             NaN           NaN
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175             NaN           NaN
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06             NaN           NaN
# 9      05D5381D-AA75-415C-94AA-00311A192699             NaN           NaN
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1             NaN           NaN
# 11     690B1653-B55B-405A-9E4F-0032C72511B4             NaN           NaN
# ...

# %%
for i in range(len(df_phy183_184_215)):
    stu = df_phy183_184_215['placeholderID'][i]
    if stu in phy183_stu:
        stu2 = df_phy183.loc[df_phy183['placeholderID'] == stu]
        stu_loc = int(df_phy183.index.get_indexer_for((df_phy183[df_phy183['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184_215.set_value(i, 'term_seq_id_183', stu2['term_seq_id'][stu_loc])
                df_phy183_184_215.set_value(i, 'term_code_183', stu2['term_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'grade_code_183', stu2['grade_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'repeat_status_flag_183', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_code_183', stu2['major_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_name_183', stu2['major_name'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_type_183', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184_215.set_value(i, 'term_seq_id_183', 'DNT PHY183')
        df_phy183_184_215.set_value(i, 'term_code_183', 'DNT PHY183')
        df_phy183_184_215.set_value(i, 'grade_code_183', 'DNT PHY183')
        df_phy183_184_215.set_value(i, 'repeat_status_flag_183', 'DNT PHY183')
        df_phy183_184_215.set_value(i, 'major_code_183', 'DNT PHY183')
        df_phy183_184_215.set_value(i, 'major_name_183', 'DNT PHY183')
        df_phy183_184_215.set_value(i, 'major_type_183', 'DNT PHY183')
        
        
        
    if stu in phy184_stu:
        stu2 = df_phy184.loc[df_phy184['placeholderID'] == stu]
        stu_loc = int(df_phy184.index.get_indexer_for((df_phy184[df_phy184['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184_215.set_value(i, 'term_seq_id_184', stu2['term_seq_id'][stu_loc])
                df_phy183_184_215.set_value(i, 'term_code_184', stu2['term_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'grade_code_184', stu2['grade_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'repeat_status_flag_184', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_code_184', stu2['major_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_name_184', stu2['major_name'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_type_184', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184_215.set_value(i, 'term_seq_id_184', 'DNT PHY184')
        df_phy183_184_215.set_value(i, 'term_code_184', 'DNT PHY184')
        df_phy183_184_215.set_value(i, 'grade_code_184', 'DNT PHY184')
        df_phy183_184_215.set_value(i, 'repeat_status_flag_184', 'DNT PHY184')
        df_phy183_184_215.set_value(i, 'major_code_184', 'DNT PHY184')
        df_phy183_184_215.set_value(i, 'major_name_184', 'DNT PHY184')
        df_phy183_184_215.set_value(i, 'major_type_184', 'DNT PHY184')
        
        
    if stu in phy215_stu:
        stu2 = df_phy215.loc[df_phy215['placeholderID'] == stu]
        stu_loc = int(df_phy215.index.get_indexer_for((df_phy215[df_phy215['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184_215.set_value(i, 'term_seq_id_215', stu2['term_seq_id'][stu_loc])
                df_phy183_184_215.set_value(i, 'term_code_215', stu2['term_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'grade_code_215', stu2['grade_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'repeat_status_flag_215', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_code_215', stu2['major_code'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_name_215', stu2['major_name'][stu_loc])
                df_phy183_184_215.set_value(i, 'major_type_215', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184_215.set_value(i, 'term_seq_id_215', 'DNT PHY215')
        df_phy183_184_215.set_value(i, 'term_code_215', 'DNT PHY215')
        df_phy183_184_215.set_value(i, 'grade_code_215', 'DNT PHY215')
        df_phy183_184_215.set_value(i, 'repeat_status_flag_215', 'DNT PHY215')
        df_phy183_184_215.set_value(i, 'major_code_215', 'DNT PHY215')
        df_phy183_184_215.set_value(i, 'major_name_215', 'DNT PHY215')
        df_phy183_184_215.set_value(i, 'major_type_215', 'DNT PHY215')

# %%
df_phy183_184_215
# Out:
#                               placeholderID term_seq_id_183 term_code_183  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23            1116          SS12
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408            1076          SS08
# 2      576F115D-3565-420F-AAE7-0007266980A5            1044          FS04
# 3      6D1640CF-6645-4899-9055-00089F24558C            1024          FS02
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0            1096          SS10
# 5      7393F06D-4793-444D-AF49-0014F5819E0C            1056          SS06
# 6      44B51964-1C8D-43D2-815D-00177931EC51            1134          FS13
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175            1074          FS07
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06            1042          US04
# 9      05D5381D-AA75-415C-94AA-00311A192699            1046          SS05
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1            1014          FS01
# 11     690B1653-B55B-405A-9E4F-0032C72511B4            1036          SS04
# ...

# %%
pd.value_counts(df_phy183_184_215['major_type_183'])
# Out:
# Engineering             8975
# Other STEM              5316
# DNT PHY183              2607
# non STEM                 567
# Physics/Astrophysics     545
# Lyman Briggs             465
# No Preference            243
# Education                 17
# Other Major                3
# Name: major_type_183, dtype: int64

# %%
pd.value_counts(df_phy183_184_215['major_type_184'])
# Out:
# Engineering             7987
# DNT PHY184              5007
# Other STEM              4432
# Physics/Astrophysics     742
# non STEM                 265
# Lyman Briggs             253
# No Preference             46
# Education                  6
# Name: major_type_184, dtype: int64

# %%
pd.value_counts(df_phy183_184_215['major_type_215'])
# Out:
# DNT PHY215              17509
# Physics/Astrophysics      779
# Other STEM                274
# Lyman Briggs               87
# Engineering                64
# non STEM                   21
# No Preference               3
# Other Major                 1
# Name: major_type_215, dtype: int64

# %%
from pandas import ExcelWriter
writer = ExcelWriter('Classes_phy183_184_215_any.xlsx')
df_phy183_184_215.to_excel(writer, 'Sheet1')
writer.save()

# %% [markdown]
# ### PHY183-->PHY184-->PHY215-->PHY321

# %%
df_phy183 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '183')|(df_classes_all['crse_code'] == '183A')|(df_classes_all['crse_code'] == '183B')]
df_phy183 = df_phy183.reset_index(drop=True)
df_phy183 = df_phy183.drop_duplicates(subset='placeholderID', keep='last')
df_phy183 = df_phy183.reset_index(drop=True)
df_phy183
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1116      SS12       PHY
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408         1076      SS08       PHY
# 2      576F115D-3565-420F-AAE7-0007266980A5         1044      FS04       PHY
# 3      6D1640CF-6645-4899-9055-00089F24558C         1024      FS02       PHY
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0         1096      SS10       PHY
# 5      7393F06D-4793-444D-AF49-0014F5819E0C         1056      SS06       PHY
# 6      44B51964-1C8D-43D2-815D-00177931EC51         1134      FS13       PHY
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175         1074      FS07       PHY
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06         1042      US04       PHY
# 9      05D5381D-AA75-415C-94AA-00311A192699         1046      SS05       PHY
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1         1014      FS01       PHY
# ...

# %%
df_phy184 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '184')|(df_classes_all['crse_code'] == '184A')|(df_classes_all['crse_code'] == '184B')]
df_phy184 = df_phy184.reset_index(drop=True)
df_phy184 = df_phy184.drop_duplicates(subset='placeholderID', keep='last')
df_phy184 = df_phy184.reset_index(drop=True)
df_phy184
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1134      FS13       PHY
# 1      0A9563A9-3C0B-48AA-B8E2-0006E536F36F         1016      SS02       PHY
# 2      576F115D-3565-420F-AAE7-0007266980A5         1046      SS05       PHY
# 3      6D1640CF-6645-4899-9055-00089F24558C         1026      SS03       PHY
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0         1114      FS11       PHY
# 5      7393F06D-4793-444D-AF49-0014F5819E0C         1074      FS07       PHY
# 6      44B51964-1C8D-43D2-815D-00177931EC51         1136      SS14       PHY
# 7      A85B8D33-65D2-4301-AE36-001A401BFF01         1144      FS14       PHY
# 8      8AB50F5A-6467-43B0-818C-00215CA7A175         1082      US08       PHY
# 9      88361B49-55BC-4BE5-942A-0026B54AEB06         1036      SS04       PHY
# 10     05D5381D-AA75-415C-94AA-00311A192699         1052      US05       PHY
# ...

# %%
df_phy215 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '215')|(df_classes_all['crse_code'] == '215B')]
df_phy215 = df_phy215.reset_index(drop=True)
df_phy215 = df_phy215.drop_duplicates(subset='placeholderID', keep='last')
df_phy215 = df_phy215.reset_index(drop=True)
df_phy215
# Out:
#                              placeholderID  term_seq_id term_code subj_code  \
# 0     8AB50F5A-6467-43B0-818C-00215CA7A175         1084      FS08       PHY
# 1     83F2F832-0F1A-4F4F-B73A-0031C962795C         1056      SS06       PHY
# 2     1E193C37-DBD0-4C80-B30F-00AE0B75B3A9         1066      SS07       PHY
# 3     AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF         1036      SS04       PHY
# 4     128348BA-5824-43F5-9D26-0106E6B9A7BD         1086      SS09       PHY
# 5     11F8C2B2-8913-46A7-89EE-01A651EED9C6         1046      SS05       PHY
# 6     7AFA4E6D-8545-481E-8091-01B1545A8084         1144      FS14       PHY
# 7     4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1136      SS14       PHY
# 8     D071B6F5-D901-47CD-B63E-02357DDB88FD         1046      SS05       PHY
# 9     E3D03F30-1DC3-42CB-A0E1-02C36D876838         1154      FS15       PHY
# 10    C4396ED4-8A37-41B6-A1DD-032F43A6192A         1054      FS05       PHY
# ...

# %%
df_phy321 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '321')]
df_phy321 = df_phy321.reset_index(drop=True)
df_phy321 = df_phy321.drop_duplicates(subset='placeholderID', keep='last')
df_phy321 = df_phy321.reset_index(drop=True)
df_phy321
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    8AB50F5A-6467-43B0-818C-00215CA7A175         1086      SS09       PHY
# 1    83F2F832-0F1A-4F4F-B73A-0031C962795C         1056      SS06       PHY
# 2    1E193C37-DBD0-4C80-B30F-00AE0B75B3A9         1066      SS07       PHY
# 3    128348BA-5824-43F5-9D26-0106E6B9A7BD         1086      SS09       PHY
# 4    11F8C2B2-8913-46A7-89EE-01A651EED9C6         1056      SS06       PHY
# 5    7AFA4E6D-8545-481E-8091-01B1545A8084         1154      FS15       PHY
# 6    4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1136      SS14       PHY
# 7    D071B6F5-D901-47CD-B63E-02357DDB88FD         1046      SS05       PHY
# 8    E3D03F30-1DC3-42CB-A0E1-02C36D876838         1156      SS16       PHY
# 9    079A93F5-2652-4EB8-AF3B-03CC287F0621         1026      SS03       PHY
# 10   630B3D27-B564-4321-BAD9-044D48AC0DA7         1156      SS16       PHY
# ...

# %%
phy183_stu = []
for i in range(len(df_phy183)):
    if df_phy183['placeholderID'][i] in phy183_stu:
        continue
    else:
        phy183_stu.append(df_phy183['placeholderID'][i])
        
phy183_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  '1E72FA2E-BAA7-4224-9425-0033CD0BDA55',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '39D7AB4A-40DC-4133-AA5A-00421E7C9263',
#  '111190B4-0FE3-4CE3-B20B-004EC7A4A385',
#  '0B94E3B1-C42F-4825-864B-004FB6E27FCD',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F6B64904-ED07-49ED-843A-00616EA7751A',
# ...

# %%
phy184_stu = []
for i in range(len(df_phy184)):
    if df_phy184['placeholderID'][i] in phy184_stu:
        continue
    else:
        phy184_stu.append(df_phy184['placeholderID'][i])
        
phy184_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '0A9563A9-3C0B-48AA-B8E2-0006E536F36F',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  'A85B8D33-65D2-4301-AE36-001A401BFF01',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '4ECD5846-280F-4672-BFDC-003FDB8076F0',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F0332AAB-A2FB-405D-AE88-006294175189',
#  '1BB808D0-971D-4A46-8379-006D750D3398',
#  '3A666148-2D71-49B5-81ED-007DBB634DDD',
# ...

# %%
phy215_stu = []
for i in range(len(df_phy215)):
    if df_phy215['placeholderID'][i] in phy215_stu:
        continue
    else:
        phy215_stu.append(df_phy215['placeholderID'][i])
        
phy215_stu
# Out:
# ['8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  '1E193C37-DBD0-4C80-B30F-00AE0B75B3A9',
#  'AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF',
#  '128348BA-5824-43F5-9D26-0106E6B9A7BD',
#  '11F8C2B2-8913-46A7-89EE-01A651EED9C6',
#  '7AFA4E6D-8545-481E-8091-01B1545A8084',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
#  'D071B6F5-D901-47CD-B63E-02357DDB88FD',
#  'E3D03F30-1DC3-42CB-A0E1-02C36D876838',
#  'C4396ED4-8A37-41B6-A1DD-032F43A6192A',
#  '200D80F1-AF5D-485E-8509-033337DD56C7',
#  '079A93F5-2652-4EB8-AF3B-03CC287F0621',
#  '37523C48-3534-4A05-842A-03D274E396FA',
#  'A49DDFD9-D0A4-490C-8A4C-03DA12D0439A',
#  'BE8F33D0-4FD1-44D6-98C3-03EB2B1A7A7C',
#  '630B3D27-B564-4321-BAD9-044D48AC0DA7',
#  'D487A88D-98DF-45E4-8F8D-045C16CC0A12',
#  '688CD527-98FD-485B-90E1-049E6CA8C844',
#  'EF2B5097-2ED0-4D31-A1C5-04DDBC9D7ABB',
#  'D12100AD-C82F-488E-9A36-04EF37B34108',
#  'EBB6CC53-D524-4E0B-85D4-050BC8679B93',
#  '70DF2CC3-E347-403F-8191-057EB097D566',
# ...

# %%
phy321_stu = []
for i in range(len(df_phy321)):
    if df_phy321['placeholderID'][i] in phy321_stu:
        continue
    else:
        phy321_stu.append(df_phy321['placeholderID'][i])
        
phy321_stu
# Out:
# ['8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  '1E193C37-DBD0-4C80-B30F-00AE0B75B3A9',
#  '128348BA-5824-43F5-9D26-0106E6B9A7BD',
#  '11F8C2B2-8913-46A7-89EE-01A651EED9C6',
#  '7AFA4E6D-8545-481E-8091-01B1545A8084',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
#  'D071B6F5-D901-47CD-B63E-02357DDB88FD',
#  'E3D03F30-1DC3-42CB-A0E1-02C36D876838',
#  '079A93F5-2652-4EB8-AF3B-03CC287F0621',
#  '630B3D27-B564-4321-BAD9-044D48AC0DA7',
#  'D487A88D-98DF-45E4-8F8D-045C16CC0A12',
#  'EBB6CC53-D524-4E0B-85D4-050BC8679B93',
#  '70DF2CC3-E347-403F-8191-057EB097D566',
#  'E2FD8BF4-4569-4434-8150-058B4338E86E',
#  'B78DCFD0-EE1C-4631-ADFC-06522103A216',
#  'D43593E9-91AE-4F49-BE30-067283FF0A1F',
#  '89DEF1E2-27B3-48A2-BF28-067D20E61342',
#  'E6C7F8DC-6795-4BF3-B3C0-069BF7BB386D',
#  'AA09DDB0-35DE-43D1-A45D-0700DD5BB713',
#  '8304C1F0-BE06-40F4-A8E0-070399E8C0C5',
#  '391E7412-7679-4342-AAAC-075463B04D74',
#  '9639B776-25D5-47E1-90D6-0766A62CFBC2',
# ...

# %%
ls_phy183_184_215_321_stu = []
for i in phy183_stu:
    if i in ls_phy183_184_215_321_stu:
        continue
    else:
        ls_phy183_184_215_321_stu.append(i)
        
for j in phy184_stu:
    if j in ls_phy183_184_215_321_stu:
        continue
    else:
        ls_phy183_184_215_321_stu.append(j)
        
for k in phy215_stu:
    if k in ls_phy183_184_215_321_stu:
        continue
    else:
        ls_phy183_184_215_321_stu.append(k)
        
for m in phy321_stu:
    if m in ls_phy183_184_215_321_stu:
        continue
    else:
        ls_phy183_184_215_321_stu.append(m)

# %%
ls_phy183_184_215_321_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  '1E72FA2E-BAA7-4224-9425-0033CD0BDA55',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '39D7AB4A-40DC-4133-AA5A-00421E7C9263',
#  '111190B4-0FE3-4CE3-B20B-004EC7A4A385',
#  '0B94E3B1-C42F-4825-864B-004FB6E27FCD',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F6B64904-ED07-49ED-843A-00616EA7751A',
# ...

# %%
cols = ('placeholderID', 'term_seq_id_183', 'term_code_183', 'grade_code_183', 'repeat_status_flag_183', 'major_code_183', 'major_name_183', 'major_type_183', 'term_seq_id_184', 'term_code_184', 'grade_code_184', 'repeat_status_flag_184', 'major_code_184', 'major_name_184', 'major_type_184', 'term_seq_id_215', 'term_code_215', 'grade_code_215', 'repeat_status_flag_215', 'major_code_215', 'major_name_215', 'major_type_215', 'term_seq_id_321', 'term_code_321', 'grade_code_321', 'repeat_status_flag_321', 'major_code_321', 'major_name_321', 'major_type_321')
df_phy183_184_215_321 = pd.DataFrame(columns=cols)
df_phy183_184_215_321
# Out:
# Empty DataFrame
# Columns: [placeholderID, term_seq_id_183, term_code_183, grade_code_183, repeat_status_flag_183, major_code_183, major_name_183, major_type_183, term_seq_id_184, term_code_184, grade_code_184, repeat_status_flag_184, major_code_184, major_name_184, major_type_184, term_seq_id_215, term_code_215, grade_code_215, repeat_status_flag_215, major_code_215, major_name_215, major_type_215, term_seq_id_321, term_code_321, grade_code_321, repeat_status_flag_321, major_code_321, major_name_321, major_type_321]
# Index: []

# %%
for i in range(len(ls_phy183_184_215_321_stu)):
    df_phy183_184_215_321.set_value(i, 'placeholderID', ls_phy183_184_215_321_stu[i])

# %%
df_phy183_184_215_321
# Out:
#                               placeholderID term_seq_id_183 term_code_183  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23             NaN           NaN
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408             NaN           NaN
# 2      576F115D-3565-420F-AAE7-0007266980A5             NaN           NaN
# 3      6D1640CF-6645-4899-9055-00089F24558C             NaN           NaN
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0             NaN           NaN
# 5      7393F06D-4793-444D-AF49-0014F5819E0C             NaN           NaN
# 6      44B51964-1C8D-43D2-815D-00177931EC51             NaN           NaN
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175             NaN           NaN
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06             NaN           NaN
# 9      05D5381D-AA75-415C-94AA-00311A192699             NaN           NaN
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1             NaN           NaN
# 11     690B1653-B55B-405A-9E4F-0032C72511B4             NaN           NaN
# ...

# %%
for i in range(len(df_phy183_184_215_321)):
    stu = df_phy183_184_215_321['placeholderID'][i]
    if stu in phy183_stu:
        stu2 = df_phy183.loc[df_phy183['placeholderID'] == stu]
        stu_loc = int(df_phy183.index.get_indexer_for((df_phy183[df_phy183['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184_215_321.set_value(i, 'term_seq_id_183', stu2['term_seq_id'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'term_code_183', stu2['term_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'grade_code_183', stu2['grade_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'repeat_status_flag_183', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_code_183', stu2['major_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_name_183', stu2['major_name'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_type_183', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184_215_321.set_value(i, 'term_seq_id_183', 'DNT PHY183')
        df_phy183_184_215_321.set_value(i, 'term_code_183', 'DNT PHY183')
        df_phy183_184_215_321.set_value(i, 'grade_code_183', 'DNT PHY183')
        df_phy183_184_215_321.set_value(i, 'repeat_status_flag_183', 'DNT PHY183')
        df_phy183_184_215_321.set_value(i, 'major_code_183', 'DNT PHY183')
        df_phy183_184_215_321.set_value(i, 'major_name_183', 'DNT PHY183')
        df_phy183_184_215_321.set_value(i, 'major_type_183', 'DNT PHY183')
        
        
        
    if stu in phy184_stu:
        stu2 = df_phy184.loc[df_phy184['placeholderID'] == stu]
        stu_loc = int(df_phy184.index.get_indexer_for((df_phy184[df_phy184['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184_215_321.set_value(i, 'term_seq_id_184', stu2['term_seq_id'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'term_code_184', stu2['term_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'grade_code_184', stu2['grade_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'repeat_status_flag_184', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_code_184', stu2['major_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_name_184', stu2['major_name'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_type_184', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184_215_321.set_value(i, 'term_seq_id_184', 'DNT PHY184')
        df_phy183_184_215_321.set_value(i, 'term_code_184', 'DNT PHY184')
        df_phy183_184_215_321.set_value(i, 'grade_code_184', 'DNT PHY184')
        df_phy183_184_215_321.set_value(i, 'repeat_status_flag_184', 'DNT PHY184')
        df_phy183_184_215_321.set_value(i, 'major_code_184', 'DNT PHY184')
        df_phy183_184_215_321.set_value(i, 'major_name_184', 'DNT PHY184')
        df_phy183_184_215_321.set_value(i, 'major_type_184', 'DNT PHY184')
        
        
    if stu in phy215_stu:
        stu2 = df_phy215.loc[df_phy215['placeholderID'] == stu]
        stu_loc = int(df_phy215.index.get_indexer_for((df_phy215[df_phy215['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184_215_321.set_value(i, 'term_seq_id_215', stu2['term_seq_id'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'term_code_215', stu2['term_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'grade_code_215', stu2['grade_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'repeat_status_flag_215', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_code_215', stu2['major_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_name_215', stu2['major_name'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_type_215', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184_215_321.set_value(i, 'term_seq_id_215', 'DNT PHY215')
        df_phy183_184_215_321.set_value(i, 'term_code_215', 'DNT PHY215')
        df_phy183_184_215_321.set_value(i, 'grade_code_215', 'DNT PHY215')
        df_phy183_184_215_321.set_value(i, 'repeat_status_flag_215', 'DNT PHY215')
        df_phy183_184_215_321.set_value(i, 'major_code_215', 'DNT PHY215')
        df_phy183_184_215_321.set_value(i, 'major_name_215', 'DNT PHY215')
        df_phy183_184_215_321.set_value(i, 'major_type_215', 'DNT PHY215')
        
        
    if stu in phy321_stu:
        stu2 = df_phy321.loc[df_phy321['placeholderID'] == stu]
        stu_loc = int(df_phy321.index.get_indexer_for((df_phy321[df_phy321['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy183_184_215_321.set_value(i, 'term_seq_id_321', stu2['term_seq_id'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'term_code_321', stu2['term_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'grade_code_321', stu2['grade_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'repeat_status_flag_321', stu2['repeat_status_flag'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_code_321', stu2['major_code'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_name_321', stu2['major_name'][stu_loc])
                df_phy183_184_215_321.set_value(i, 'major_type_321', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy183_184_215_321.set_value(i, 'term_seq_id_321', 'DNT PHY321')
        df_phy183_184_215_321.set_value(i, 'term_code_321', 'DNT PHY321')
        df_phy183_184_215_321.set_value(i, 'grade_code_321', 'DNT PHY321')
        df_phy183_184_215_321.set_value(i, 'repeat_status_flag_321', 'DNT PHY321')
        df_phy183_184_215_321.set_value(i, 'major_code_321', 'DNT PHY321')
        df_phy183_184_215_321.set_value(i, 'major_name_321', 'DNT PHY321')
        df_phy183_184_215_321.set_value(i, 'major_type_321', 'DNT PHY321')

# %%
df_phy183_184_215_321
# Out:
#                               placeholderID term_seq_id_183 term_code_183  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23            1116          SS12
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408            1076          SS08
# 2      576F115D-3565-420F-AAE7-0007266980A5            1044          FS04
# 3      6D1640CF-6645-4899-9055-00089F24558C            1024          FS02
# 4      48EFA8F7-284D-42EE-92D6-000CCD9385F0            1096          SS10
# 5      7393F06D-4793-444D-AF49-0014F5819E0C            1056          SS06
# 6      44B51964-1C8D-43D2-815D-00177931EC51            1134          FS13
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175            1074          FS07
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06            1042          US04
# 9      05D5381D-AA75-415C-94AA-00311A192699            1046          SS05
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1            1014          FS01
# 11     690B1653-B55B-405A-9E4F-0032C72511B4            1036          SS04
# ...

# %%
pd.value_counts(df_phy183_184_215_321['major_type_183'])
# Out:
# Engineering             8975
# Other STEM              5316
# DNT PHY183              2629
# non STEM                 567
# Physics/Astrophysics     545
# Lyman Briggs             465
# No Preference            243
# Education                 17
# Other Major                3
# Name: major_type_183, dtype: int64

# %%
pd.value_counts(df_phy183_184_215_321['major_type_184'])
# Out:
# Engineering             7987
# DNT PHY184              5029
# Other STEM              4432
# Physics/Astrophysics     742
# non STEM                 265
# Lyman Briggs             253
# No Preference             46
# Education                  6
# Name: major_type_184, dtype: int64

# %%
pd.value_counts(df_phy183_184_215_321['major_type_215'])
# Out:
# DNT PHY215              17531
# Physics/Astrophysics      779
# Other STEM                274
# Lyman Briggs               87
# Engineering                64
# non STEM                   21
# No Preference               3
# Other Major                 1
# Name: major_type_215, dtype: int64

# %%
pd.value_counts(df_phy183_184_215_321['major_type_321'])
# Out:
# DNT PHY321              17862
# Physics/Astrophysics      680
# Other STEM                125
# Lyman Briggs               56
# Engineering                28
# non STEM                    7
# No Preference               1
# Other Major                 1
# Name: major_type_321, dtype: int64

# %%
from pandas import ExcelWriter
writer = ExcelWriter('Classes_phy183_184_215_321_any.xlsx')
df_phy183_184_215_321.to_excel(writer, 'Sheet1')
writer.save()

# %% [markdown]
# ### MTH132-->MTH133-->MTH234-->MTH235

# %%
df_mth132 = df_classes_all[(df_classes_all['subj_code'] == 'MTH')&(df_classes_all['crse_code'] == '132')]
df_mth132 = df_mth132.reset_index(drop=True)
df_mth132 = df_mth132.drop_duplicates(subset='placeholderID', keep='last')
df_mth132 = df_mth132.reset_index(drop=True)
df_mth132
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1114      FS11       MTH
# 1      DAF3AEBB-C359-4AAD-B03D-000273D1DFA9         1146      SS15       MTH
# 2      05A5B725-8B62-4E6C-94D3-00034ACD5408         1074      FS07       MTH
# 3      576F115D-3565-420F-AAE7-0007266980A5         1034      FS03       MTH
# 4      83E1B1A6-B838-41FC-956A-0008052B2095         1154      FS15       MTH
# 5      6E191FD5-474E-4D26-B998-000852F9CA80         1164      FS16       MTH
# 6      6D1640CF-6645-4899-9055-00089F24558C         1014      FS01       MTH
# 7      E07279B7-B3B2-4BA7-8646-000AFA893745         1014      FS01       MTH
# 8      8851CF67-90DA-4EF9-9A9C-000C6FDC83A0         1026      SS03       MTH
# 9      48EFA8F7-284D-42EE-92D6-000CCD9385F0         1094      FS09       MTH
# 10     A2B1AC72-93EF-4374-B1BC-0012DDC8EF6B         1094      FS09       MTH
# ...

# %%
df_mth133 = df_classes_all[(df_classes_all['subj_code'] == 'MTH')&(df_classes_all['crse_code'] == '133')]
df_mth133 = df_mth133.reset_index(drop=True)
df_mth133 = df_mth133.drop_duplicates(subset='placeholderID', keep='last')
df_mth133 = df_mth133.reset_index(drop=True)
df_mth133
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1124      FS12       MTH
# 1      05A5B725-8B62-4E6C-94D3-00034ACD5408         1076      SS08       MTH
# 2      576F115D-3565-420F-AAE7-0007266980A5         1036      SS04       MTH
# 3      6D1640CF-6645-4899-9055-00089F24558C         1016      SS02       MTH
# 4      E07279B7-B3B2-4BA7-8646-000AFA893745         1024      FS02       MTH
# 5      48EFA8F7-284D-42EE-92D6-000CCD9385F0         1096      SS10       MTH
# 6      FEB97EC7-E52D-409F-A9B2-001471E184EB         1096      SS10       MTH
# 7      7393F06D-4793-444D-AF49-0014F5819E0C         1056      SS06       MTH
# 8      44B51964-1C8D-43D2-815D-00177931EC51         1124      FS12       MTH
# 9      600D6ABC-A845-4E36-91F2-001EF011E088         1104      FS10       MTH
# 10     8AB50F5A-6467-43B0-818C-00215CA7A175         1074      FS07       MTH
# ...

# %%
df_mth234 = df_classes_all[(df_classes_all['subj_code'] == 'MTH')&(df_classes_all['crse_code'] == '234')]
df_mth234 = df_mth234.reset_index(drop=True)
df_mth234 = df_mth234.drop_duplicates(subset='placeholderID', keep='last')
df_mth234 = df_mth234.reset_index(drop=True)
df_mth234
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23         1126      SS13       MTH
# 1      576F115D-3565-420F-AAE7-0007266980A5         1046      SS05       MTH
# 2      6D1640CF-6645-4899-9055-00089F24558C         1024      FS02       MTH
# 3      7393F06D-4793-444D-AF49-0014F5819E0C         1064      FS06       MTH
# 4      44B51964-1C8D-43D2-815D-00177931EC51         1126      SS13       MTH
# 5      A85B8D33-65D2-4301-AE36-001A401BFF01         1144      FS14       MTH
# 6      600D6ABC-A845-4E36-91F2-001EF011E088         1106      SS11       MTH
# 7      8AB50F5A-6467-43B0-818C-00215CA7A175         1082      US08       MTH
# 8      88361B49-55BC-4BE5-942A-0026B54AEB06         1034      FS03       MTH
# 9      05D5381D-AA75-415C-94AA-00311A192699         1052      US05       MTH
# 10     3A7E4D20-56FB-439C-9529-00316EBEFBE1         1016      SS02       MTH
# ...

# %%
df_mth235 = df_classes_all[(df_classes_all['subj_code'] == 'MTH')&(df_classes_all['crse_code'] == '235')]
df_mth235 = df_mth235.reset_index(drop=True)
df_mth235 = df_mth235.drop_duplicates(subset='placeholderID', keep='last')
df_mth235 = df_mth235.reset_index(drop=True)
df_mth235
# Out:
#                               placeholderID  term_seq_id term_code subj_code  \
# 0      0A9563A9-3C0B-48AA-B8E2-0006E536F36F         1014      FS01       MTH
# 1      576F115D-3565-420F-AAE7-0007266980A5         1054      FS05       MTH
# 2      6D1640CF-6645-4899-9055-00089F24558C         1026      SS03       MTH
# 3      7393F06D-4793-444D-AF49-0014F5819E0C         1066      SS07       MTH
# 4      44B51964-1C8D-43D2-815D-00177931EC51         1134      FS13       MTH
# 5      A85B8D33-65D2-4301-AE36-001A401BFF01         1146      SS15       MTH
# 6      8AB50F5A-6467-43B0-818C-00215CA7A175         1082      US08       MTH
# 7      88361B49-55BC-4BE5-942A-0026B54AEB06         1036      SS04       MTH
# 8      05D5381D-AA75-415C-94AA-00311A192699         1054      FS05       MTH
# 9      3A7E4D20-56FB-439C-9529-00316EBEFBE1         1024      FS02       MTH
# 10     690B1653-B55B-405A-9E4F-0032C72511B4         1034      FS03       MTH
# ...

# %%
mth132_stu = []
for i in range(len(df_mth132)):
    if df_mth132['placeholderID'][i] in mth132_stu:
        continue
    else:
        mth132_stu.append(df_mth132['placeholderID'][i])
        
mth132_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  'DAF3AEBB-C359-4AAD-B03D-000273D1DFA9',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '83E1B1A6-B838-41FC-956A-0008052B2095',
#  '6E191FD5-474E-4D26-B998-000852F9CA80',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  'E07279B7-B3B2-4BA7-8646-000AFA893745',
#  '8851CF67-90DA-4EF9-9A9C-000C6FDC83A0',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  'A2B1AC72-93EF-4374-B1BC-0012DDC8EF6B',
#  'FEB97EC7-E52D-409F-A9B2-001471E184EB',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '8E45F348-8A12-4457-90C5-001F983CF48D',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  'FB223326-7D4E-40C8-BFB7-002237E28817',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '92C2E0D5-5127-4C85-B446-002FFE27F598',
#  '934D8DDC-9349-46CC-894C-003139932328',
#  '1E72FA2E-BAA7-4224-9425-0033CD0BDA55',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  'B96FEDA6-A8BD-4E2E-AB18-0036E2B8E518',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
# ...

# %%
mth133_stu = []
for i in range(len(df_mth133)):
    if df_mth133['placeholderID'][i] in mth133_stu:
        continue
    else:
        mth133_stu.append(df_mth133['placeholderID'][i])
        
mth133_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  'E07279B7-B3B2-4BA7-8646-000AFA893745',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  'FEB97EC7-E52D-409F-A9B2-001471E184EB',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  '600D6ABC-A845-4E36-91F2-001EF011E088',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '54584609-991D-48E1-B8B9-002BC76F1C95',
#  '92C2E0D5-5127-4C85-B446-002FFE27F598',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  'B96FEDA6-A8BD-4E2E-AB18-0036E2B8E518',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '48A26972-8222-4EDC-B796-003D19BE73F0',
#  '4ECD5846-280F-4672-BFDC-003FDB8076F0',
#  '9A49FBEC-18AE-43EB-9E7E-00417051AA21',
# ...

# %%
mth234_stu = []
for i in range(len(df_mth234)):
    if df_mth234['placeholderID'][i] in mth234_stu:
        continue
    else:
        mth234_stu.append(df_mth234['placeholderID'][i])
        
mth234_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  'A85B8D33-65D2-4301-AE36-001A401BFF01',
#  '600D6ABC-A845-4E36-91F2-001EF011E088',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
#  '4ECD5846-280F-4672-BFDC-003FDB8076F0',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F0332AAB-A2FB-405D-AE88-006294175189',
#  '05A0BFF4-89C4-4AF3-AAB1-006D2841B156',
#  '1BB808D0-971D-4A46-8379-006D750D3398',
#  '17D6FD53-2FD1-404F-B3A4-0072D215F7EA',
#  'A4C7F9D8-6A56-4917-A4B7-007C7D2B6086',
# ...

# %%
mth235_stu = []
for i in range(len(df_mth235)):
    if df_mth235['placeholderID'][i] in mth235_stu:
        continue
    else:
        mth235_stu.append(df_mth235['placeholderID'][i])
        
mth235_stu
# Out:
# ['0A9563A9-3C0B-48AA-B8E2-0006E536F36F',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '44B51964-1C8D-43D2-815D-00177931EC51',
#  'A85B8D33-65D2-4301-AE36-001A401BFF01',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '05D5381D-AA75-415C-94AA-00311A192699',
#  '3A7E4D20-56FB-439C-9529-00316EBEFBE1',
#  '690B1653-B55B-405A-9E4F-0032C72511B4',
#  '4ECD5846-280F-4672-BFDC-003FDB8076F0',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  'DB549C75-56CB-45E7-A374-00552FAABF80',
#  '53B74058-CCC6-4EA7-A11D-005581FCF7CF',
#  '9BB4CCDA-7BF4-4E0A-B320-005DCF34CA59',
#  'F0332AAB-A2FB-405D-AE88-006294175189',
#  '1BB808D0-971D-4A46-8379-006D750D3398',
#  'D61E575B-64C5-45DA-BB8F-0077DA0D32B4',
#  '3A666148-2D71-49B5-81ED-007DBB634DDD',
#  'D86A6DC0-FE66-4970-9A00-0087B88069C0',
#  '22B175DE-021B-4528-B83B-008C1B30D8EC',
#  'D6463000-F81E-4CEC-BE87-009737330180',
# ...

# %%
ls_mth132_133_234_235_stu = []
for i in mth132_stu:
    if i in ls_mth132_133_234_235_stu:
        continue
    else:
        ls_mth132_133_234_235_stu.append(i)
        
for j in mth133_stu:
    if j in ls_mth132_133_234_235_stu:
        continue
    else:
        ls_mth132_133_234_235_stu.append(j)
        
for k in mth234_stu:
    if k in ls_mth132_133_234_235_stu:
        continue
    else:
        ls_mth132_133_234_235_stu.append(k)
        
for m in mth235_stu:
    if m in ls_mth132_133_234_235_stu:
        continue
    else:
        ls_mth132_133_234_235_stu.append(m)

# %%
ls_mth132_133_234_235_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  'DAF3AEBB-C359-4AAD-B03D-000273D1DFA9',
#  '05A5B725-8B62-4E6C-94D3-00034ACD5408',
#  '576F115D-3565-420F-AAE7-0007266980A5',
#  '83E1B1A6-B838-41FC-956A-0008052B2095',
#  '6E191FD5-474E-4D26-B998-000852F9CA80',
#  '6D1640CF-6645-4899-9055-00089F24558C',
#  'E07279B7-B3B2-4BA7-8646-000AFA893745',
#  '8851CF67-90DA-4EF9-9A9C-000C6FDC83A0',
#  '48EFA8F7-284D-42EE-92D6-000CCD9385F0',
#  'A2B1AC72-93EF-4374-B1BC-0012DDC8EF6B',
#  'FEB97EC7-E52D-409F-A9B2-001471E184EB',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '8E45F348-8A12-4457-90C5-001F983CF48D',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  'FB223326-7D4E-40C8-BFB7-002237E28817',
#  '88361B49-55BC-4BE5-942A-0026B54AEB06',
#  '92C2E0D5-5127-4C85-B446-002FFE27F598',
#  '934D8DDC-9349-46CC-894C-003139932328',
#  '1E72FA2E-BAA7-4224-9425-0033CD0BDA55',
#  'C5263047-98CE-42F8-B0E9-0036128C57C6',
#  'B96FEDA6-A8BD-4E2E-AB18-0036E2B8E518',
#  '6DA8B102-F67E-4427-AA90-00387EAD243E',
# ...

# %%
cols = ('placeholderID', 'term_seq_id_132', 'term_code_132', 'grade_code_132', 'repeat_status_flag_132', 'major_code_132', 'major_name_132', 'major_type_132', 'term_seq_id_133', 'term_code_133', 'grade_code_133', 'repeat_status_flag_133', 'major_code_133', 'major_name_133', 'major_type_133', 'term_seq_id_234', 'term_code_234', 'grade_code_234', 'repeat_status_flag_234', 'major_code_234', 'major_name_234', 'major_type_234', 'term_seq_id_235', 'term_code_235', 'grade_code_235', 'repeat_status_flag_235', 'major_code_235', 'major_name_235', 'major_type_235')
df_mth132_133_234_235 = pd.DataFrame(columns=cols)
df_mth132_133_234_235
# Out:
# Empty DataFrame
# Columns: [placeholderID, term_seq_id_132, term_code_132, grade_code_132, repeat_status_flag_132, major_code_132, major_name_132, major_type_132, term_seq_id_133, term_code_133, grade_code_133, repeat_status_flag_133, major_code_133, major_name_133, major_type_133, term_seq_id_234, term_code_234, grade_code_234, repeat_status_flag_234, major_code_234, major_name_234, major_type_234, term_seq_id_235, term_code_235, grade_code_235, repeat_status_flag_235, major_code_235, major_name_235, major_type_235]
# Index: []

# %%
for i in range(len(ls_mth132_133_234_235_stu)):
    df_mth132_133_234_235.set_value(i, 'placeholderID', ls_mth132_133_234_235_stu[i])

# %%
df_mth132_133_234_235
# Out:
#                               placeholderID term_seq_id_132 term_code_132  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23             NaN           NaN
# 1      DAF3AEBB-C359-4AAD-B03D-000273D1DFA9             NaN           NaN
# 2      05A5B725-8B62-4E6C-94D3-00034ACD5408             NaN           NaN
# 3      576F115D-3565-420F-AAE7-0007266980A5             NaN           NaN
# 4      83E1B1A6-B838-41FC-956A-0008052B2095             NaN           NaN
# 5      6E191FD5-474E-4D26-B998-000852F9CA80             NaN           NaN
# 6      6D1640CF-6645-4899-9055-00089F24558C             NaN           NaN
# 7      E07279B7-B3B2-4BA7-8646-000AFA893745             NaN           NaN
# 8      8851CF67-90DA-4EF9-9A9C-000C6FDC83A0             NaN           NaN
# 9      48EFA8F7-284D-42EE-92D6-000CCD9385F0             NaN           NaN
# 10     A2B1AC72-93EF-4374-B1BC-0012DDC8EF6B             NaN           NaN
# 11     FEB97EC7-E52D-409F-A9B2-001471E184EB             NaN           NaN
# ...

# %%
for i in range(len(df_mth132_133_234_235)):
    stu = df_mth132_133_234_235['placeholderID'][i]
    if stu in mth132_stu:
        stu2 = df_mth132.loc[df_mth132['placeholderID'] == stu]
        stu_loc = int(df_mth132.index.get_indexer_for((df_mth132[df_mth132['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_mth132_133_234_235.set_value(i, 'term_seq_id_132', stu2['term_seq_id'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'term_code_132', stu2['term_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'grade_code_132', stu2['grade_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'repeat_status_flag_132', stu2['repeat_status_flag'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_code_132', stu2['major_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_name_132', stu2['major_name'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_type_132', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_mth132_133_234_235.set_value(i, 'term_seq_id_132', 'DNT MTH132')
        df_mth132_133_234_235.set_value(i, 'term_code_132', 'DNT MTH132')
        df_mth132_133_234_235.set_value(i, 'grade_code_132', 'DNT MTH132')
        df_mth132_133_234_235.set_value(i, 'repeat_status_flag_132', 'DNT MTH132')
        df_mth132_133_234_235.set_value(i, 'major_code_132', 'DNT MTH132')
        df_mth132_133_234_235.set_value(i, 'major_name_132', 'DNT MTH132')
        df_mth132_133_234_235.set_value(i, 'major_type_132', 'DNT MTH132')
        
        
    if stu in mth133_stu:
        stu2 = df_mth133.loc[df_mth133['placeholderID'] == stu]
        stu_loc = int(df_mth133.index.get_indexer_for((df_mth133[df_mth133['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_mth132_133_234_235.set_value(i, 'term_seq_id_133', stu2['term_seq_id'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'term_code_133', stu2['term_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'grade_code_133', stu2['grade_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'repeat_status_flag_133', stu2['repeat_status_flag'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_code_133', stu2['major_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_name_133', stu2['major_name'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_type_133', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_mth132_133_234_235.set_value(i, 'term_seq_id_133', 'DNT MTH133')
        df_mth132_133_234_235.set_value(i, 'term_code_133', 'DNT MTH133')
        df_mth132_133_234_235.set_value(i, 'grade_code_133', 'DNT MTH133')
        df_mth132_133_234_235.set_value(i, 'repeat_status_flag_133', 'DNT MTH133')
        df_mth132_133_234_235.set_value(i, 'major_code_133', 'DNT MTH133')
        df_mth132_133_234_235.set_value(i, 'major_name_133', 'DNT MTH133')
        df_mth132_133_234_235.set_value(i, 'major_type_133', 'DNT MTH133')

        
    if stu in mth234_stu:
        stu2 = df_mth234.loc[df_mth234['placeholderID'] == stu]
        stu_loc = int(df_mth234.index.get_indexer_for((df_mth234[df_mth234['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_mth132_133_234_235.set_value(i, 'term_seq_id_234', stu2['term_seq_id'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'term_code_234', stu2['term_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'grade_code_234', stu2['grade_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'repeat_status_flag_234', stu2['repeat_status_flag'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_code_234', stu2['major_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_name_234', stu2['major_name'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_type_234', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_mth132_133_234_235.set_value(i, 'term_seq_id_234', 'DNT MTH234')
        df_mth132_133_234_235.set_value(i, 'term_code_234', 'DNT MTH234')
        df_mth132_133_234_235.set_value(i, 'grade_code_234', 'DNT MTH234')
        df_mth132_133_234_235.set_value(i, 'repeat_status_flag_234', 'DNT MTH234')
        df_mth132_133_234_235.set_value(i, 'major_code_234', 'DNT MTH234')
        df_mth132_133_234_235.set_value(i, 'major_name_234', 'DNT MTH234')
        df_mth132_133_234_235.set_value(i, 'major_type_234', 'DNT MTH234')
     
    
    if stu in mth235_stu:
        stu2 = df_mth235.loc[df_mth235['placeholderID'] == stu]
        stu_loc = int(df_mth235.index.get_indexer_for((df_mth235[df_mth235['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_mth132_133_234_235.set_value(i, 'term_seq_id_235', stu2['term_seq_id'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'term_code_235', stu2['term_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'grade_code_235', stu2['grade_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'repeat_status_flag_235', stu2['repeat_status_flag'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_code_235', stu2['major_code'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_name_235', stu2['major_name'][stu_loc])
                df_mth132_133_234_235.set_value(i, 'major_type_235', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_mth132_133_234_235.set_value(i, 'term_seq_id_235', 'DNT MTH235')
        df_mth132_133_234_235.set_value(i, 'term_code_235', 'DNT MTH235')
        df_mth132_133_234_235.set_value(i, 'grade_code_235', 'DNT MTH235')
        df_mth132_133_234_235.set_value(i, 'repeat_status_flag_235', 'DNT MTH235')
        df_mth132_133_234_235.set_value(i, 'major_code_235', 'DNT MTH235')
        df_mth132_133_234_235.set_value(i, 'major_name_235', 'DNT MTH235')
        df_mth132_133_234_235.set_value(i, 'major_type_235', 'DNT MTH235')

# %%
df_mth132_133_234_235
# Out:
#                               placeholderID term_seq_id_132 term_code_132  \
# 0      3C1C5E03-FA14-4F6A-B0C6-000250988C23            1114          FS11
# 1      DAF3AEBB-C359-4AAD-B03D-000273D1DFA9            1146          SS15
# 2      05A5B725-8B62-4E6C-94D3-00034ACD5408            1074          FS07
# 3      576F115D-3565-420F-AAE7-0007266980A5            1034          FS03
# 4      83E1B1A6-B838-41FC-956A-0008052B2095            1154          FS15
# 5      6E191FD5-474E-4D26-B998-000852F9CA80            1164          FS16
# 6      6D1640CF-6645-4899-9055-00089F24558C            1014          FS01
# 7      E07279B7-B3B2-4BA7-8646-000AFA893745            1014          FS01
# 8      8851CF67-90DA-4EF9-9A9C-000C6FDC83A0            1026          SS03
# 9      48EFA8F7-284D-42EE-92D6-000CCD9385F0            1094          FS09
# 10     A2B1AC72-93EF-4374-B1BC-0012DDC8EF6B            1094          FS09
# 11     FEB97EC7-E52D-409F-A9B2-001471E184EB            1094          FS09
# ...

# %%
pd.value_counts(df_mth132_133_234_235['major_type_132'])
# Out:
# DNT MTH132              10405
# Other STEM               9908
# Engineering              8605
# non STEM                 2892
# No Preference            1716
# Education                 554
# Physics/Astrophysics      432
# Lyman Briggs              250
# Other Major                 5
# Name: major_type_132, dtype: int64

# %%
pd.value_counts(df_mth132_133_234_235['major_type_133'])
# Out:
# DNT MTH133              17383
# Engineering              7749
# Other STEM               6459
# non STEM                 1243
# Physics/Astrophysics      605
# No Preference             591
# Education                 405
# Lyman Briggs              317
# Other Major                15
# Name: major_type_133, dtype: int64

# %%
pd.value_counts(df_mth132_133_234_235['major_type_234'])
# Out:
# DNT MTH234              19710
# Engineering              8126
# Other STEM               4576
# non STEM                  860
# Physics/Astrophysics      807
# Lyman Briggs              324
# No Preference             225
# Education                 115
# Other Major                24
# Name: major_type_234, dtype: int64

# %%
pd.value_counts(df_mth132_133_234_235['major_type_235'])
# Out:
# DNT MTH235              24327
# Engineering              7280
# Other STEM               1884
# Physics/Astrophysics      856
# non STEM                  228
# Lyman Briggs              148
# No Preference              35
# Other Major                 6
# Education                   3
# Name: major_type_235, dtype: int64

# %%
from pandas import ExcelWriter
writer = ExcelWriter('Classes_mth132_133_234_235_any.xlsx')
df_mth132_133_234_235.to_excel(writer, 'Sheet1')
writer.save()

# %% [markdown]
# ### PHY191-->PHY192

# %%
df_phy191 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '191')]
df_phy191 = df_phy191.reset_index(drop=True)
df_phy191 = df_phy191.drop_duplicates(subset='placeholderID', keep='last')
df_phy191 = df_phy191.reset_index(drop=True)
df_phy191
# Out:
#                              placeholderID  term_seq_id term_code subj_code  \
# 0     3C1C5E03-FA14-4F6A-B0C6-000250988C23         1144      FS14       PHY
# 1     7393F06D-4793-444D-AF49-0014F5819E0C         1064      FS06       PHY
# 2     8AB50F5A-6467-43B0-818C-00215CA7A175         1084      FS08       PHY
# 3     83F2F832-0F1A-4F4F-B73A-0031C962795C         1054      FS05       PHY
# 4     3839BEF6-ACB4-434E-BA07-0053F1EF8D58         1154      FS15       PHY
# 5     192E13D1-9393-4672-A0B9-0095E718FC3D         1154      FS15       PHY
# 6     AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF         1034      FS03       PHY
# 7     6529D71D-CFB4-4D66-8F11-00D87F49D974         1154      FS15       PHY
# 8     9E2EF9ED-B11E-4966-9E70-0102321863C1         1154      FS15       PHY
# 9     CCA69938-7470-424C-8ED7-0123AB745909         1144      FS14       PHY
# 10    38FDC08C-2589-4F3D-A9D2-0126F3F2F873         1144      FS14       PHY
# ...

# %%
df_phy192 = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '192')]
df_phy192 = df_phy192.reset_index(drop=True)
df_phy192 = df_phy192.drop_duplicates(subset='placeholderID', keep='last')
df_phy192 = df_phy192.reset_index(drop=True)
df_phy192
# Out:
#                              placeholderID  term_seq_id term_code subj_code  \
# 0     8AB50F5A-6467-43B0-818C-00215CA7A175         1086      SS09       PHY
# 1     83F2F832-0F1A-4F4F-B73A-0031C962795C         1056      SS06       PHY
# 2     192E13D1-9393-4672-A0B9-0095E718FC3D         1156      SS16       PHY
# 3     CCA69938-7470-424C-8ED7-0123AB745909         1146      SS15       PHY
# 4     38FDC08C-2589-4F3D-A9D2-0126F3F2F873         1146      SS15       PHY
# 5     CF8B3DD1-D737-484A-A41E-0176F2F89DD7         1026      SS03       PHY
# 6     11F8C2B2-8913-46A7-89EE-01A651EED9C6         1066      SS07       PHY
# 7     7AFA4E6D-8545-481E-8091-01B1545A8084         1146      SS15       PHY
# 8     E486DDA4-4620-44A0-BF7D-01B77561E380         1136      SS14       PHY
# 9     4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1156      SS16       PHY
# 10    D071B6F5-D901-47CD-B63E-02357DDB88FD         1046      SS05       PHY
# ...

# %%
phy191_stu = []
for i in range(len(df_phy191)):
    if df_phy191['placeholderID'][i] in phy191_stu:
        continue
    else:
        phy191_stu.append(df_phy191['placeholderID'][i])
        
phy191_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  '192E13D1-9393-4672-A0B9-0095E718FC3D',
#  'AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF',
#  '6529D71D-CFB4-4D66-8F11-00D87F49D974',
#  '9E2EF9ED-B11E-4966-9E70-0102321863C1',
#  'CCA69938-7470-424C-8ED7-0123AB745909',
#  '38FDC08C-2589-4F3D-A9D2-0126F3F2F873',
#  '6A0BF90E-5069-4061-8EE8-013062A7C1D1',
#  '1B6F8257-BA86-40B3-B985-01353D591F90',
#  '08FCBA30-C117-4314-9714-013AE331E82F',
#  'CF8B3DD1-D737-484A-A41E-0176F2F89DD7',
#  '2603E3F5-94A0-4EAD-91C3-019585E316E0',
#  '11F8C2B2-8913-46A7-89EE-01A651EED9C6',
#  '7AFA4E6D-8545-481E-8091-01B1545A8084',
#  'E486DDA4-4620-44A0-BF7D-01B77561E380',
#  '8AADE860-781C-4CCB-8789-01C82A436F88',
#  'E829C0C6-859C-4DBA-B2F4-01DF87253B01',
#  '9BC32615-E1B8-4D21-98DB-01E60AB456F1',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
# ...

# %%
phy192_stu = []
for i in range(len(df_phy192)):
    if df_phy192['placeholderID'][i] in phy192_stu:
        continue
    else:
        phy192_stu.append(df_phy192['placeholderID'][i])
        
phy192_stu
# Out:
# ['8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  '192E13D1-9393-4672-A0B9-0095E718FC3D',
#  'CCA69938-7470-424C-8ED7-0123AB745909',
#  '38FDC08C-2589-4F3D-A9D2-0126F3F2F873',
#  'CF8B3DD1-D737-484A-A41E-0176F2F89DD7',
#  '11F8C2B2-8913-46A7-89EE-01A651EED9C6',
#  '7AFA4E6D-8545-481E-8091-01B1545A8084',
#  'E486DDA4-4620-44A0-BF7D-01B77561E380',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
#  'D071B6F5-D901-47CD-B63E-02357DDB88FD',
#  '5E6025EA-2AD9-4366-9CBE-0293B0E80D87',
#  'E3D03F30-1DC3-42CB-A0E1-02C36D876838',
#  'D6DE0662-DAFD-4D8B-AB47-02E6A789676E',
#  '8B8B6985-02F6-428D-B9CA-03B799610174',
#  '688CD527-98FD-485B-90E1-049E6CA8C844',
#  'EAD3DA42-9630-428C-AB3C-04B4835BA200',
#  '5468A830-0882-482F-B34C-04F1B758B4EF',
#  'EBB6CC53-D524-4E0B-85D4-050BC8679B93',
#  '4EFDB6EE-7BB1-4D05-8DCD-053838F3A9EE',
#  '70DF2CC3-E347-403F-8191-057EB097D566',
#  'E2FD8BF4-4569-4434-8150-058B4338E86E',
#  'AFB4CE61-18DB-46B3-A63D-05C72D6AB9E7',
# ...

# %%
ls_phy191_192_stu = []
for i in phy191_stu:
    if i in ls_phy191_192_stu:
        continue
    else:
        ls_phy191_192_stu.append(i)
        
for j in phy192_stu:
    if j in ls_phy191_192_stu:
        continue
    else:
        ls_phy191_192_stu.append(j)

# %%
ls_phy191_192_stu
# Out:
# ['3C1C5E03-FA14-4F6A-B0C6-000250988C23',
#  '7393F06D-4793-444D-AF49-0014F5819E0C',
#  '8AB50F5A-6467-43B0-818C-00215CA7A175',
#  '83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  '3839BEF6-ACB4-434E-BA07-0053F1EF8D58',
#  '192E13D1-9393-4672-A0B9-0095E718FC3D',
#  'AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF',
#  '6529D71D-CFB4-4D66-8F11-00D87F49D974',
#  '9E2EF9ED-B11E-4966-9E70-0102321863C1',
#  'CCA69938-7470-424C-8ED7-0123AB745909',
#  '38FDC08C-2589-4F3D-A9D2-0126F3F2F873',
#  '6A0BF90E-5069-4061-8EE8-013062A7C1D1',
#  '1B6F8257-BA86-40B3-B985-01353D591F90',
#  '08FCBA30-C117-4314-9714-013AE331E82F',
#  'CF8B3DD1-D737-484A-A41E-0176F2F89DD7',
#  '2603E3F5-94A0-4EAD-91C3-019585E316E0',
#  '11F8C2B2-8913-46A7-89EE-01A651EED9C6',
#  '7AFA4E6D-8545-481E-8091-01B1545A8084',
#  'E486DDA4-4620-44A0-BF7D-01B77561E380',
#  '8AADE860-781C-4CCB-8789-01C82A436F88',
#  'E829C0C6-859C-4DBA-B2F4-01DF87253B01',
#  '9BC32615-E1B8-4D21-98DB-01E60AB456F1',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
# ...

# %%
cols = ('placeholderID', 'term_seq_id_191', 'term_code_191', 'grade_code_191', 'repeat_status_flag_191', 'major_code_191', 'major_name_191', 'major_type_191', 'term_seq_id_192', 'term_code_192', 'grade_code_192', 'repeat_status_flag_192', 'major_code_192', 'major_name_192', 'major_type_192')
df_phy191_192 = pd.DataFrame(columns=cols)
df_phy191_192
# Out:
# Empty DataFrame
# Columns: [placeholderID, term_seq_id_191, term_code_191, grade_code_191, repeat_status_flag_191, major_code_191, major_name_191, major_type_191, term_seq_id_192, term_code_192, grade_code_192, repeat_status_flag_192, major_code_192, major_name_192, major_type_192]
# Index: []

# %%
for i in range(len(ls_phy191_192_stu)):
    df_phy191_192.set_value(i, 'placeholderID', ls_phy191_192_stu[i])

# %%
df_phy191_192
# Out:
#                              placeholderID term_seq_id_191 term_code_191  \
# 0     3C1C5E03-FA14-4F6A-B0C6-000250988C23             NaN           NaN
# 1     7393F06D-4793-444D-AF49-0014F5819E0C             NaN           NaN
# 2     8AB50F5A-6467-43B0-818C-00215CA7A175             NaN           NaN
# 3     83F2F832-0F1A-4F4F-B73A-0031C962795C             NaN           NaN
# 4     3839BEF6-ACB4-434E-BA07-0053F1EF8D58             NaN           NaN
# 5     192E13D1-9393-4672-A0B9-0095E718FC3D             NaN           NaN
# 6     AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF             NaN           NaN
# 7     6529D71D-CFB4-4D66-8F11-00D87F49D974             NaN           NaN
# 8     9E2EF9ED-B11E-4966-9E70-0102321863C1             NaN           NaN
# 9     CCA69938-7470-424C-8ED7-0123AB745909             NaN           NaN
# 10    38FDC08C-2589-4F3D-A9D2-0126F3F2F873             NaN           NaN
# 11    6A0BF90E-5069-4061-8EE8-013062A7C1D1             NaN           NaN
# ...

# %%
for i in range(len(df_phy191_192)):
    stu = df_phy191_192['placeholderID'][i]
    if stu in phy191_stu:
        stu2 = df_phy191.loc[df_phy191['placeholderID'] == stu]
        stu_loc = int(df_phy191.index.get_indexer_for((df_phy191[df_phy191['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy191_192.set_value(i, 'term_seq_id_191', stu2['term_seq_id'][stu_loc])
                df_phy191_192.set_value(i, 'term_code_191', stu2['term_code'][stu_loc])
                df_phy191_192.set_value(i, 'grade_code_191', stu2['grade_code'][stu_loc])
                df_phy191_192.set_value(i, 'repeat_status_flag_191', stu2['repeat_status_flag'][stu_loc])
                df_phy191_192.set_value(i, 'major_code_191', stu2['major_code'][stu_loc])
                df_phy191_192.set_value(i, 'major_name_191', stu2['major_name'][stu_loc])
                df_phy191_192.set_value(i, 'major_type_191', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy191_192.set_value(i, 'term_seq_id_191', 'DNT PHY191')
        df_phy191_192.set_value(i, 'term_code_191', 'DNT PHY191')
        df_phy191_192.set_value(i, 'grade_code_191', 'DNT PHY191')
        df_phy191_192.set_value(i, 'repeat_status_flag_191', 'DNT PHY191')
        df_phy191_192.set_value(i, 'major_code_191', 'DNT PHY191')
        df_phy191_192.set_value(i, 'major_name_191', 'DNT PHY191')
        df_phy191_192.set_value(i, 'major_type_191', 'DNT PHY191')
        
        
    if stu in phy192_stu:
        stu2 = df_phy192.loc[df_phy192['placeholderID'] == stu]
        stu_loc = int(df_phy192.index.get_indexer_for((df_phy192[df_phy192['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy191_192.set_value(i, 'term_seq_id_192', stu2['term_seq_id'][stu_loc])
                df_phy191_192.set_value(i, 'term_code_192', stu2['term_code'][stu_loc])
                df_phy191_192.set_value(i, 'grade_code_192', stu2['grade_code'][stu_loc])
                df_phy191_192.set_value(i, 'repeat_status_flag_192', stu2['repeat_status_flag'][stu_loc])
                df_phy191_192.set_value(i, 'major_code_192', stu2['major_code'][stu_loc])
                df_phy191_192.set_value(i, 'major_name_192', stu2['major_name'][stu_loc])
                df_phy191_192.set_value(i, 'major_type_192', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy191_192.set_value(i, 'term_seq_id_192', 'DNT PHY192')
        df_phy191_192.set_value(i, 'term_code_192', 'DNT PHY192')
        df_phy191_192.set_value(i, 'grade_code_192', 'DNT PHY192')
        df_phy191_192.set_value(i, 'repeat_status_flag_192', 'DNT PHY192')
        df_phy191_192.set_value(i, 'major_code_192', 'DNT PHY192')
        df_phy191_192.set_value(i, 'major_name_192', 'DNT PHY192')
        df_phy191_192.set_value(i, 'major_type_192', 'DNT PHY192')

# %%
df_phy191_192
# Out:
#                              placeholderID term_seq_id_191 term_code_191  \
# 0     3C1C5E03-FA14-4F6A-B0C6-000250988C23            1144          FS14
# 1     7393F06D-4793-444D-AF49-0014F5819E0C            1064          FS06
# 2     8AB50F5A-6467-43B0-818C-00215CA7A175            1084          FS08
# 3     83F2F832-0F1A-4F4F-B73A-0031C962795C            1054          FS05
# 4     3839BEF6-ACB4-434E-BA07-0053F1EF8D58            1154          FS15
# 5     192E13D1-9393-4672-A0B9-0095E718FC3D            1154          FS15
# 6     AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF            1034          FS03
# 7     6529D71D-CFB4-4D66-8F11-00D87F49D974            1154          FS15
# 8     9E2EF9ED-B11E-4966-9E70-0102321863C1            1154          FS15
# 9     CCA69938-7470-424C-8ED7-0123AB745909            1144          FS14
# 10    38FDC08C-2589-4F3D-A9D2-0126F3F2F873            1144          FS14
# 11    6A0BF90E-5069-4061-8EE8-013062A7C1D1            1144          FS14
# ...

# %%
pd.value_counts(df_phy191_192['major_type_191'])
# Out:
# Other STEM              1120
# Engineering              598
# Physics/Astrophysics     598
# DNT PHY191               191
# Lyman Briggs             132
# non STEM                  69
# No Preference              5
# Education                  3
# Name: major_type_191, dtype: int64

# %%
pd.value_counts(df_phy191_192['major_type_192'])
# Out:
# DNT PHY192              1370
# Other STEM               613
# Physics/Astrophysics     533
# Engineering              104
# Lyman Briggs              71
# non STEM                  21
# No Preference              2
# Education                  2
# Name: major_type_192, dtype: int64

# %%
from pandas import ExcelWriter
writer = ExcelWriter('Classes_phy191_192_any.xlsx')
df_phy191_192.to_excel(writer, 'Sheet1')
writer.save()

# %% [markdown]
# ### PHY193H--->PHY294H

# %%
df_phy193h = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '193H')]
df_phy193h = df_phy193h.reset_index(drop=True)
df_phy193h = df_phy193h.drop_duplicates(subset='placeholderID', keep='last')
df_phy193h = df_phy193h.reset_index(drop=True)
df_phy193h
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    83F2F832-0F1A-4F4F-B73A-0031C962795C         1046      SS05       PHY
# 1    EB4E280B-9ABB-4E96-9C71-005C849DB55A         1164      FS16       PHY
# 2    7174F46B-CFF3-42CD-8363-00D6EFF0FC7B         1036      SS04       PHY
# 3    6A0BF90E-5069-4061-8EE8-013062A7C1D1         1144      FS14       PHY
# 4    9BC32615-E1B8-4D21-98DB-01E60AB456F1         1086      SS09       PHY
# 5    4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1126      SS13       PHY
# 6    99C3EC77-174E-406F-9552-02D81ED4AE2E         1056      SS06       PHY
# 7    E74AEE17-EAEF-4D67-97CC-0318D8751FCD         1154      FS15       PHY
# 8    C4396ED4-8A37-41B6-A1DD-032F43A6192A         1036      SS04       PHY
# 9    37523C48-3534-4A05-842A-03D274E396FA         1154      FS15       PHY
# 10   A49DDFD9-D0A4-490C-8A4C-03DA12D0439A         1144      FS14       PHY
# ...

# %%
df_phy294h = df_classes_all[(df_classes_all['subj_code'] == 'PHY')&(df_classes_all['crse_code'] == '294H')]
df_phy294h = df_phy294h.reset_index(drop=True)
df_phy294h = df_phy294h.drop_duplicates(subset='placeholderID', keep='last')
df_phy294h = df_phy294h.reset_index(drop=True)
df_phy294h
# Out:
#                             placeholderID  term_seq_id term_code subj_code  \
# 0    83F2F832-0F1A-4F4F-B73A-0031C962795C         1054      FS05       PHY
# 1    AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF         1034      FS03       PHY
# 2    E2AFF3A5-C1D6-4AEC-BF66-00C5901C8257         1094      FS09       PHY
# 3    6A0BF90E-5069-4061-8EE8-013062A7C1D1         1146      SS15       PHY
# 4    6F66F308-7023-42EF-AC82-021101C8D2D1         1084      FS08       PHY
# 5    4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9         1134      FS13       PHY
# 6    504B943D-41E5-42D4-A17F-0228EDDA2B67         1034      FS03       PHY
# 7    59B970F6-3D73-4824-B438-0248B59414C3         1014      FS01       PHY
# 8    FA92C50D-7501-474E-8635-02C06AB98F61         1124      FS12       PHY
# 9    E74AEE17-EAEF-4D67-97CC-0318D8751FCD         1156      SS16       PHY
# 10   37523C48-3534-4A05-842A-03D274E396FA         1156      SS16       PHY
# ...

# %%
phy193h_stu = []
for i in range(len(df_phy193h)):
    if df_phy193h['placeholderID'][i] in phy193h_stu:
        continue
    else:
        phy193h_stu.append(df_phy193h['placeholderID'][i])
        
phy193h_stu
# Out:
# ['83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  'EB4E280B-9ABB-4E96-9C71-005C849DB55A',
#  '7174F46B-CFF3-42CD-8363-00D6EFF0FC7B',
#  '6A0BF90E-5069-4061-8EE8-013062A7C1D1',
#  '9BC32615-E1B8-4D21-98DB-01E60AB456F1',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
#  '99C3EC77-174E-406F-9552-02D81ED4AE2E',
#  'E74AEE17-EAEF-4D67-97CC-0318D8751FCD',
#  'C4396ED4-8A37-41B6-A1DD-032F43A6192A',
#  '37523C48-3534-4A05-842A-03D274E396FA',
#  'A49DDFD9-D0A4-490C-8A4C-03DA12D0439A',
#  '336E4C65-602C-4B75-B0A9-041BA76C4D6E',
#  'EB2AE574-F9E7-4AB3-ABFF-0480C922B154',
#  'F174FDF7-539F-4DBC-B84C-04966E84AC48',
#  'EAD3DA42-9630-428C-AB3C-04B4835BA200',
#  'EBB6CC53-D524-4E0B-85D4-050BC8679B93',
#  'D7E0BA56-B2AA-4E74-B6B5-05322BF43E77',
#  '57043237-7911-4DA2-B6FF-05B578557FC8',
#  '9AA69527-DBF9-4390-AABD-05C677C60828',
#  '2DDB0E47-F8B6-4E61-B206-061FB46B72C5',
#  'B78DCFD0-EE1C-4631-ADFC-06522103A216',
#  'F5CA2D05-464A-45DC-AFDB-0698ACD04A47',
#  'E6C7F8DC-6795-4BF3-B3C0-069BF7BB386D',
# ...

# %%
phy294h_stu = []
for i in range(len(df_phy294h)):
    if df_phy294h['placeholderID'][i] in phy294h_stu:
        continue
    else:
        phy294h_stu.append(df_phy294h['placeholderID'][i])
        
phy294h_stu
# Out:
# ['83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  'AFDFBEB8-54F8-4AA8-8D63-00BF6BF5F3BF',
#  'E2AFF3A5-C1D6-4AEC-BF66-00C5901C8257',
#  '6A0BF90E-5069-4061-8EE8-013062A7C1D1',
#  '6F66F308-7023-42EF-AC82-021101C8D2D1',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
#  '504B943D-41E5-42D4-A17F-0228EDDA2B67',
#  '59B970F6-3D73-4824-B438-0248B59414C3',
#  'FA92C50D-7501-474E-8635-02C06AB98F61',
#  'E74AEE17-EAEF-4D67-97CC-0318D8751FCD',
#  '37523C48-3534-4A05-842A-03D274E396FA',
#  'A49DDFD9-D0A4-490C-8A4C-03DA12D0439A',
#  'EB2AE574-F9E7-4AB3-ABFF-0480C922B154',
#  'EAD3DA42-9630-428C-AB3C-04B4835BA200',
#  '646A20DC-A53E-4F8D-9627-0613024A0099',
#  '2DDB0E47-F8B6-4E61-B206-061FB46B72C5',
#  'B78DCFD0-EE1C-4631-ADFC-06522103A216',
#  'F5CA2D05-464A-45DC-AFDB-0698ACD04A47',
#  '8304C1F0-BE06-40F4-A8E0-070399E8C0C5',
#  '391E7412-7679-4342-AAAC-075463B04D74',
#  '45C7D34A-ACFA-4CCF-9D09-0896ECFF0B44',
#  '175ADA8B-E11F-4CA7-8902-08CA83758049',
#  '1D68BE43-2814-4993-B576-08FF464965D0',
# ...

# %%
ls_phy193h_294h_stu = []
for i in phy193h_stu:
    if i in ls_phy193h_294h_stu:
        continue
    else:
        ls_phy193h_294h_stu.append(i)
        
for j in phy294h_stu:
    if j in ls_phy193h_294h_stu:
        continue
    else:
        ls_phy193h_294h_stu.append(j)

# %%
ls_phy193h_294h_stu
# Out:
# ['83F2F832-0F1A-4F4F-B73A-0031C962795C',
#  'EB4E280B-9ABB-4E96-9C71-005C849DB55A',
#  '7174F46B-CFF3-42CD-8363-00D6EFF0FC7B',
#  '6A0BF90E-5069-4061-8EE8-013062A7C1D1',
#  '9BC32615-E1B8-4D21-98DB-01E60AB456F1',
#  '4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9',
#  '99C3EC77-174E-406F-9552-02D81ED4AE2E',
#  'E74AEE17-EAEF-4D67-97CC-0318D8751FCD',
#  'C4396ED4-8A37-41B6-A1DD-032F43A6192A',
#  '37523C48-3534-4A05-842A-03D274E396FA',
#  'A49DDFD9-D0A4-490C-8A4C-03DA12D0439A',
#  '336E4C65-602C-4B75-B0A9-041BA76C4D6E',
#  'EB2AE574-F9E7-4AB3-ABFF-0480C922B154',
#  'F174FDF7-539F-4DBC-B84C-04966E84AC48',
#  'EAD3DA42-9630-428C-AB3C-04B4835BA200',
#  'EBB6CC53-D524-4E0B-85D4-050BC8679B93',
#  'D7E0BA56-B2AA-4E74-B6B5-05322BF43E77',
#  '57043237-7911-4DA2-B6FF-05B578557FC8',
#  '9AA69527-DBF9-4390-AABD-05C677C60828',
#  '2DDB0E47-F8B6-4E61-B206-061FB46B72C5',
#  'B78DCFD0-EE1C-4631-ADFC-06522103A216',
#  'F5CA2D05-464A-45DC-AFDB-0698ACD04A47',
#  'E6C7F8DC-6795-4BF3-B3C0-069BF7BB386D',
# ...

# %%
cols = ('placeholderID', 'term_seq_id_193h', 'term_code_193h', 'grade_code_193h', 'repeat_status_flag_193h', 'major_code_193h', 'major_name_193h', 'major_type_193h', 'term_seq_id_294h', 'term_code_294h', 'grade_code_294h', 'repeat_status_flag_294h', 'major_code_294h', 'major_name_294h', 'major_type_294h')
df_phy193h_294h = pd.DataFrame(columns=cols)
df_phy193h_294h
# Out:
# Empty DataFrame
# Columns: [placeholderID, term_seq_id_193h, term_code_193h, grade_code_193h, repeat_status_flag_193h, major_code_193h, major_name_193h, major_type_193h, term_seq_id_294h, term_code_294h, grade_code_294h, repeat_status_flag_294h, major_code_294h, major_name_294h, major_type_294h]
# Index: []

# %%
for i in range(len(ls_phy193h_294h_stu)):
    df_phy193h_294h.set_value(i, 'placeholderID', ls_phy193h_294h_stu[i])

# %%
df_phy193h_294h
# Out:
#                             placeholderID term_seq_id_193h term_code_193h  \
# 0    83F2F832-0F1A-4F4F-B73A-0031C962795C              NaN            NaN
# 1    EB4E280B-9ABB-4E96-9C71-005C849DB55A              NaN            NaN
# 2    7174F46B-CFF3-42CD-8363-00D6EFF0FC7B              NaN            NaN
# 3    6A0BF90E-5069-4061-8EE8-013062A7C1D1              NaN            NaN
# 4    9BC32615-E1B8-4D21-98DB-01E60AB456F1              NaN            NaN
# 5    4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9              NaN            NaN
# 6    99C3EC77-174E-406F-9552-02D81ED4AE2E              NaN            NaN
# 7    E74AEE17-EAEF-4D67-97CC-0318D8751FCD              NaN            NaN
# 8    C4396ED4-8A37-41B6-A1DD-032F43A6192A              NaN            NaN
# 9    37523C48-3534-4A05-842A-03D274E396FA              NaN            NaN
# 10   A49DDFD9-D0A4-490C-8A4C-03DA12D0439A              NaN            NaN
# 11   336E4C65-602C-4B75-B0A9-041BA76C4D6E              NaN            NaN
# ...

# %%
for i in range(len(df_phy193h_294h)):
    stu = df_phy193h_294h['placeholderID'][i]
    if stu in phy193h_stu:
        stu2 = df_phy193h.loc[df_phy193h['placeholderID'] == stu]
        stu_loc = int(df_phy193h.index.get_indexer_for((df_phy193h[df_phy193h['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy193h_294h.set_value(i, 'term_seq_id_193h', stu2['term_seq_id'][stu_loc])
                df_phy193h_294h.set_value(i, 'term_code_193h', stu2['term_code'][stu_loc])
                df_phy193h_294h.set_value(i, 'grade_code_193h', stu2['grade_code'][stu_loc])
                df_phy193h_294h.set_value(i, 'repeat_status_flag_193h', stu2['repeat_status_flag'][stu_loc])
                df_phy193h_294h.set_value(i, 'major_code_193h', stu2['major_code'][stu_loc])
                df_phy193h_294h.set_value(i, 'major_name_193h', stu2['major_name'][stu_loc])
                df_phy193h_294h.set_value(i, 'major_type_193h', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy193h_294h.set_value(i, 'term_seq_id_193h', 'DNT PHY193H')
        df_phy193h_294h.set_value(i, 'term_code_193h', 'DNT PHY193H')
        df_phy193h_294h.set_value(i, 'grade_code_193h', 'DNT PHY193H')
        df_phy193h_294h.set_value(i, 'repeat_status_flag_193h', 'DNT PHY193H')
        df_phy193h_294h.set_value(i, 'major_code_193h', 'DNT PHY193H')
        df_phy193h_294h.set_value(i, 'major_name_193h', 'DNT PHY193H')
        df_phy193h_294h.set_value(i, 'major_type_193h', 'DNT PHY193H')
        
        
    if stu in phy294h_stu:
        stu2 = df_phy294h.loc[df_phy294h['placeholderID'] == stu]
        stu_loc = int(df_phy294h.index.get_indexer_for((df_phy294h[df_phy294h['placeholderID'] == stu].index)))
        try:
            if stu == stu2['placeholderID'][stu_loc]:
                df_phy193h_294h.set_value(i, 'term_seq_id_294h', stu2['term_seq_id'][stu_loc])
                df_phy193h_294h.set_value(i, 'term_code_294h', stu2['term_code'][stu_loc])
                df_phy193h_294h.set_value(i, 'grade_code_294h', stu2['grade_code'][stu_loc])
                df_phy193h_294h.set_value(i, 'repeat_status_flag_294h', stu2['repeat_status_flag'][stu_loc])
                df_phy193h_294h.set_value(i, 'major_code_294h', stu2['major_code'][stu_loc])
                df_phy193h_294h.set_value(i, 'major_name_294h', stu2['major_name'][stu_loc])
                df_phy193h_294h.set_value(i, 'major_type_294h', stu2['major_type'][stu_loc])
        except:
            print('uh-oh')
    else:
        df_phy193h_294h.set_value(i, 'term_seq_id_294h', 'DNT PHY294H')
        df_phy193h_294h.set_value(i, 'term_code_294h', 'DNT PHY294H')
        df_phy193h_294h.set_value(i, 'grade_code_294h', 'DNT PHY294H')
        df_phy193h_294h.set_value(i, 'repeat_status_flag_294h', 'DNT PHY294H')
        df_phy193h_294h.set_value(i, 'major_code_294h', 'DNT PHY294H')
        df_phy193h_294h.set_value(i, 'major_name_294h', 'DNT PHY294H')
        df_phy193h_294h.set_value(i, 'major_type_294h', 'DNT PHY294H')

# %%
df_phy193h_294h
# Out:
#                             placeholderID term_seq_id_193h term_code_193h  \
# 0    83F2F832-0F1A-4F4F-B73A-0031C962795C             1046           SS05
# 1    EB4E280B-9ABB-4E96-9C71-005C849DB55A             1164           FS16
# 2    7174F46B-CFF3-42CD-8363-00D6EFF0FC7B             1036           SS04
# 3    6A0BF90E-5069-4061-8EE8-013062A7C1D1             1144           FS14
# 4    9BC32615-E1B8-4D21-98DB-01E60AB456F1             1086           SS09
# 5    4054748C-0CC4-4AD4-9DB2-0222A4FEDCB9             1126           SS13
# 6    99C3EC77-174E-406F-9552-02D81ED4AE2E             1056           SS06
# 7    E74AEE17-EAEF-4D67-97CC-0318D8751FCD             1154           FS15
# 8    C4396ED4-8A37-41B6-A1DD-032F43A6192A             1036           SS04
# 9    37523C48-3534-4A05-842A-03D274E396FA             1154           FS15
# 10   A49DDFD9-D0A4-490C-8A4C-03DA12D0439A             1144           FS14
# 11   336E4C65-602C-4B75-B0A9-041BA76C4D6E             1026           SS03
# ...

# %%
pd.value_counts(df_phy193h_294h['major_type_193h'])
# Out:
# Physics/Astrophysics    216
# Engineering             158
# Other STEM              146
# DNT PHY193H             142
# Lyman Briggs             96
# non STEM                 34
# No Preference            16
# Education                 2
# Other Major               1
# Name: major_type_193h, dtype: int64

# %%
pd.value_counts(df_phy193h_294h['major_type_294h'])
# Out:
# DNT PHY294H             424
# Physics/Astrophysics    160
# Engineering             101
# Other STEM               84
# Lyman Briggs             32
# non STEM                  7
# No Preference             2
# Education                 1
# Name: major_type_294h, dtype: int64

# %%
from pandas import ExcelWriter
writer = ExcelWriter('Classes_phy193h_phy294h_any.xlsx')
df_phy193h_294h.to_excel(writer, 'Sheet1')
writer.save()
